# %% [markdown]
# # Importing Required Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Import the Dataset

# %%
df = pd.read_csv("dataset.csv") #Imported Dataset
# Out:
# C:\Users\deagn\AppData\Local\Temp\ipykernel_8964\2394031820.py:1: DtypeWarning: Columns (3,4,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("dataset.csv") #Imported Dataset

# %% [markdown]
# # 1.)Feature Engineering and Exploratory Data Analysis

# %%
df.rename(columns = {'class':'OrbitType'}, inplace = True) #Renaming column class to avoid confusion with keyword

# %%
pd.set_option("display.max_columns", None) #Changing settings to display all columns
df.head(5) #Show first 5 rows in the dataset
# Out:
#          id    spkid       full_name pdes     name prefix neo pha     H  \
# 0  a0000001  2000001         1 Ceres    1    Ceres    NaN   N   N  3.40
# 1  a0000002  2000002        2 Pallas    2   Pallas    NaN   N   N  4.20
# 2  a0000003  2000003          3 Juno    3     Juno    NaN   N   N  5.33
# 3  a0000004  2000004         4 Vesta    4    Vesta    NaN   N   N  3.00
# 4  a0000005  2000005       5 Astraea    5  Astraea    NaN   N   N  6.90
#
#    diameter  albedo  diameter_sigma orbit_id      epoch  epoch_mjd  \
# 0   939.400  0.0900           0.200   JPL 47  2458600.5      58600
# 1   545.000  0.1010          18.000   JPL 37  2459000.5      59000
# 2   246.596  0.2140          10.594  JPL 112  2459000.5      59000
# 3   525.400  0.4228           0.200   JPL 35  2458600.5      58600
# 4   106.699  0.2740           3.140  JPL 114  2459000.5      59000
#
#     epoch_cal equinox         e         a         q          i          om  \
# ...

# %%
df.shape #Show the number of rows and columns
# Out:
# (958524, 45)

# %%
df.info()  #Give the count of no of non empty rows in each column and nature of each column
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 958524 entries, 0 to 958523
# Data columns (total 45 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   id              958524 non-null  object
#  1   spkid           958524 non-null  int64
#  2   full_name       958524 non-null  object
#  3   pdes            958524 non-null  object
#  4   name            22064 non-null   object
#  5   prefix          18 non-null      object
#  6   neo             958520 non-null  object
#  7   pha             938603 non-null  object
#  8   H               952261 non-null  float64
#  9   diameter        136209 non-null  float64
#  10  albedo          135103 non-null  float64
#  11  diameter_sigma  136081 non-null  float64
#  12  orbit_id        958524 non-null  object
#  13  epoch           958524 non-null  float64
#  14  epoch_mjd       958524 non-null  int64
#  15  epoch_cal       958524 non-null  float64
# ...

# %%
df.describe()
# Out:
#               spkid              H       diameter         albedo  \
# count  9.585240e+05  952261.000000  136209.000000  135103.000000
# mean   3.810114e+06      16.906411       5.506429       0.130627
# std    6.831541e+06       1.790405       9.425164       0.110323
# min    2.000001e+06      -1.100000       0.002500       0.001000
# 25%    2.239632e+06      16.100000       2.780000       0.053000
# 50%    2.479262e+06      16.900000       3.972000       0.079000
# 75%    3.752518e+06      17.714000       5.765000       0.190000
# max    5.401723e+07      33.200000     939.400000       1.000000
#
#        diameter_sigma         epoch      epoch_mjd     epoch_cal  \
# count   136081.000000  9.585240e+05  958524.000000  9.585240e+05
# mean         0.479184  2.458869e+06   58868.781950  2.019693e+07
# std          0.782895  7.016716e+02     701.671573  1.930354e+04
# min          0.000500  2.425052e+06   25051.000000  1.927062e+07
# ...

# %%
df.describe(include = 'object')
# Out:
#               id     full_name    pdes   name prefix     neo     pha orbit_id  \
# count     958524        958524  958524  22064     18  958520  938603   958524
# unique    958524        958524  958524  22064      1       2       2     4690
# top     a0000001       1 Ceres       1  Ceres      A       N       N        1
# freq           1             1       1      1     18  935625  936537    50142
#
#        equinox OrbitType
# count   958524    958524
# unique       1        13
# top      J2000       MBA
# freq    958524    855954

# %% [markdown]
# # Removing Duplicate Rows

# %%
df.drop_duplicates() #Dropping Duplicate Values if any
# Out:
#               id    spkid          full_name      pdes     name prefix neo  \
# 0       a0000001  2000001            1 Ceres         1    Ceres    NaN   N
# 1       a0000002  2000002           2 Pallas         2   Pallas    NaN   N
# 2       a0000003  2000003             3 Juno         3     Juno    NaN   N
# 3       a0000004  2000004            4 Vesta         4    Vesta    NaN   N
# 4       a0000005  2000005          5 Astraea         5  Astraea    NaN   N
# ...          ...      ...                ...       ...      ...    ...  ..
# 958519  bPLS6013  3246801         (6013 P-L)  6013 P-L      NaN    NaN   N
# 958520  bPLS6331  3246834         (6331 P-L)  6331 P-L      NaN    NaN   N
# 958521  bPLS6344  3013075         (6344 P-L)  6344 P-L      NaN    NaN   Y
# 958522  bT2S2060  3246457         (2060 T-2)  2060 T-2      NaN    NaN   N
# 958523  bT3S2678  3246553         (2678 T-3)  2678 T-3      NaN    NaN   N
#
# ...

# %% [markdown]
# # 1.1) Handling Missing/NaN values

# %%
df.isnull().sum()  #We calculate the no of rows with null values in each column
# Out:
# id                     0
# spkid                  0
# full_name              0
# pdes                   0
# name              936460
# prefix            958506
# neo                    4
# pha                19921
# H                   6263
# diameter          822315
# albedo            823421
# diameter_sigma    822443
# orbit_id               0
# epoch                  0
# epoch_mjd              0
# epoch_cal              0
# equinox                0
# e                      0
# a                      0
# q                      0
# i                      0
# om                     0
# w                      0
# ma                     1
# ad                     4
# n                      0
# tp                     0
# tp_cal                 0
# per                    4
# per_y                  1
# moid               19921
# moid_ld              127
# sigma_e            19922
# sigma_a            19922
# sigma_q            19922
# sigma_i            19922
# sigma_om           19922
# ...

# %% [markdown]
# plt.figure(figsize = (30,30))  #plotting heatmap to see distribution of missing values
# sns.heatmap(df.isnull())

# %%
df.isnull().sum()/df.shape[0] *100 #Converting into percentage of Missing values
# Out:
# id                 0.000000
# spkid              0.000000
# full_name          0.000000
# pdes               0.000000
# name              97.698128
# prefix            99.998122
# neo                0.000417
# pha                2.078300
# H                  0.653400
# diameter          85.789714
# albedo            85.905100
# diameter_sigma    85.803068
# orbit_id           0.000000
# epoch              0.000000
# epoch_mjd          0.000000
# epoch_cal          0.000000
# equinox            0.000000
# e                  0.000000
# a                  0.000000
# q                  0.000000
# i                  0.000000
# om                 0.000000
# w                  0.000000
# ma                 0.000104
# ad                 0.000417
# n                  0.000000
# tp                 0.000000
# tp_cal             0.000000
# per                0.000417
# per_y              0.000104
# moid               2.078300
# moid_ld            0.013250
# sigma_e            2.078404
# ...

# %% [markdown]
# numerical_features = df.select_dtypes(include=['number'])
# correlation_matrix = numerical_features.corr()
#
# # Plot correlation matrix using seaborn
# plt.figure(figsize=(20, 10))
# sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
# plt.title('Correlation Matrix')
# plt.show()

# %%
df.isnull().sum()/df.shape[0] *100
# Out:
# id                 0.000000
# spkid              0.000000
# full_name          0.000000
# pdes               0.000000
# name              97.698128
# prefix            99.998122
# neo                0.000417
# pha                2.078300
# H                  0.653400
# diameter          85.789714
# albedo            85.905100
# diameter_sigma    85.803068
# orbit_id           0.000000
# epoch              0.000000
# epoch_mjd          0.000000
# epoch_cal          0.000000
# equinox            0.000000
# e                  0.000000
# a                  0.000000
# q                  0.000000
# i                  0.000000
# om                 0.000000
# w                  0.000000
# ma                 0.000104
# ad                 0.000417
# n                  0.000000
# tp                 0.000000
# tp_cal             0.000000
# per                0.000417
# per_y              0.000104
# moid               2.078300
# moid_ld            0.013250
# sigma_e            2.078404
# ...

# %%
df['OrbitType'].unique()
# Out:
# array(['MBA', 'OMB', 'MCA', 'AMO', 'IMB', 'TJN', 'CEN', 'APO', 'ATE',
#        'AST', 'TNO', 'IEO', 'HYA'], dtype=object)

# %%
df = df.drop(['sigma_e', 'sigma_a', 'sigma_q', 'sigma_i', 'sigma_om', 'sigma_w', 'sigma_ma','sigma_ad','sigma_n','sigma_tp','sigma_per','id','spkid','full_name','pdes'], axis=1)

# %%
df = df.drop(['name', 'prefix', 'diameter', 'albedo', 'diameter_sigma'], axis=1)

# %%
df.shape
# Out:
# (958524, 25)

# %%
df.describe(include = object)
# Out:
#            neo     pha orbit_id equinox OrbitType
# count   958520  938603   958524  958524    958524
# unique       2       2     4690       1        13
# top          N       N        1   J2000       MBA
# freq    935625  936537    50142  958524    855954

# %%
df = df.drop(['equinox'],axis = 1)

# %%
df.shape
# Out:
# (958524, 24)

# %%
df.describe()
# Out:
#                    H         epoch      epoch_mjd     epoch_cal  \
# count  952261.000000  9.585240e+05  958524.000000  9.585240e+05
# mean       16.906411  2.458869e+06   58868.781950  2.019693e+07
# std         1.790405  7.016716e+02     701.671573  1.930354e+04
# min        -1.100000  2.425052e+06   25051.000000  1.927062e+07
# 25%        16.100000  2.459000e+06   59000.000000  2.020053e+07
# 50%        16.900000  2.459000e+06   59000.000000  2.020053e+07
# 75%        17.714000  2.459000e+06   59000.000000  2.020053e+07
# max        33.200000  2.459000e+06   59000.000000  2.020053e+07
#
#                    e              a              q              i  \
# count  958524.000000  958524.000000  958524.000000  958524.000000
# mean        0.156116       2.902143       2.394887       9.054901
# std         0.092643      39.719503       2.139246       6.637656
# min         0.000000  -14702.447872       0.070511       0.007744
# ...

# %%
df.head(10)
# Out:
#   neo pha     H orbit_id      epoch  epoch_mjd   epoch_cal         e  \
# 0   N   N  3.40   JPL 47  2458600.5      58600  20190427.0  0.076009
# 1   N   N  4.20   JPL 37  2459000.5      59000  20200531.0  0.229972
# 2   N   N  5.33  JPL 112  2459000.5      59000  20200531.0  0.256936
# 3   N   N  3.00   JPL 35  2458600.5      58600  20190427.0  0.088721
# 4   N   N  6.90  JPL 114  2459000.5      59000  20200531.0  0.190913
# 5   N   N  5.80   JPL 89  2459000.5      59000  20200531.0  0.203219
# 6   N   N  5.60      110  2459000.5      59000  20200531.0  0.230145
# 7   N   N  6.50  JPL 118  2459000.5      59000  20200531.0  0.155833
# 8   N   N  6.30  JPL 116  2459000.5      59000  20200531.0  0.123300
# 9   N   N  5.50   JPL 96  2459000.5      59000  20200531.0  0.112117
#
#           a         q          i          om           w          ma  \
# 0  2.769165  2.558684  10.594067   80.305531   73.597695   77.372098
# ...

# %%
df['epoch_mjd'].unique()
# Out:
# array([58600, 59000, 55926, ..., 37204, 41956, 43429], dtype=int64)

# %%
df=df.drop(['orbit_id'],axis = 1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 958524 entries, 0 to 958523
# Data columns (total 23 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   neo        958520 non-null  object
#  1   pha        938603 non-null  object
#  2   H          952261 non-null  float64
#  3   epoch      958524 non-null  float64
#  4   epoch_mjd  958524 non-null  int64
#  5   epoch_cal  958524 non-null  float64
#  6   e          958524 non-null  float64
#  7   a          958524 non-null  float64
#  8   q          958524 non-null  float64
#  9   i          958524 non-null  float64
#  10  om         958524 non-null  float64
#  11  w          958524 non-null  float64
#  12  ma         958523 non-null  float64
#  13  ad         958520 non-null  float64
#  14  n          958524 non-null  float64
#  15  tp         958524 non-null  float64
#  16  tp_cal     958524 non-null  float64
#  17  per        958520 non-null  float64
# ...

# %%
a = df.select_dtypes('number')
# Select string and object columns.
b = df.select_dtypes('object')

# Fill numeric columns with mean.
df[a.columns] = a.fillna(a.mean())
# Fill object columns with mode.
df[b.columns] = b.fillna(b.agg(lambda x: x.mode().values[0]))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 958524 entries, 0 to 958523
# Data columns (total 23 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   neo        958524 non-null  object
#  1   pha        958524 non-null  object
#  2   H          958524 non-null  float64
#  3   epoch      958524 non-null  float64
#  4   epoch_mjd  958524 non-null  int64
#  5   epoch_cal  958524 non-null  float64
#  6   e          958524 non-null  float64
#  7   a          958524 non-null  float64
#  8   q          958524 non-null  float64
#  9   i          958524 non-null  float64
#  10  om         958524 non-null  float64
#  11  w          958524 non-null  float64
#  12  ma         958524 non-null  float64
#  13  ad         958524 non-null  float64
#  14  n          958524 non-null  float64
#  15  tp         958524 non-null  float64
#  16  tp_cal     958524 non-null  float64
#  17  per        958524 non-null  float64
# ...

# %%
df['neo'].replace(['N', 'Y'],
                        [0, 1], inplace=True)

# %%
df['pha'].replace(['N', 'Y'],
                        [0, 1], inplace=True)

# %% [markdown]
# ## Outlier Removal

# %%
df.describe()
# Out:
#                  neo            pha              H         epoch  \
# count  958524.000000  958524.000000  958524.000000  9.585240e+05
# mean        0.023886       0.002155      16.906411  2.458869e+06
# std         0.152693       0.046376       1.784546  7.016716e+02
# min         0.000000       0.000000      -1.100000  2.425052e+06
# 25%         0.000000       0.000000      16.100000  2.459000e+06
# 50%         0.000000       0.000000      16.900000  2.459000e+06
# 75%         0.000000       0.000000      17.700000  2.459000e+06
# max         1.000000       1.000000      33.200000  2.459000e+06
#
#            epoch_mjd     epoch_cal              e              a  \
# count  958524.000000  9.585240e+05  958524.000000  958524.000000
# mean    58868.781950  2.019693e+07       0.156116       2.902143
# std       701.671573  1.930354e+04       0.092643      39.719503
# min     25051.000000  1.927062e+07       0.000000  -14702.447872
# ...

# %%
sns.distplot(df['moid'])
# Out:
# C:\Users\deagn\AppData\Local\Temp\ipykernel_3360\3394653794.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['moid'])
# <Axes: xlabel='moid', ylabel='Density'>

# %%
sns.boxplot(df['moid'])
# Out:
# <Axes: >

# %% [markdown]
# ## 1) Zscore

# %%
upper_limit = df['moid'].mean() + 3*df['moid'].std()
lower_limit = df['moid'].mean() - 3*df['moid'].std()
print('upper limit:', upper_limit)
print('lower limit:', lower_limit)
# Out:
# upper limit: 7.817766051459262
# lower limit: -4.9874412847125935

# %%
df.loc[(df['moid'] > upper_limit) | (df['moid'] < lower_limit)]
# Out:
#         neo  pha        H      epoch  epoch_mjd   epoch_cal         e  \
# 7065      0    0   9.6000  2459000.5      59000  20200531.0  0.517555
# 10198     0    0   6.6000  2459000.5      59000  20200531.0  0.169256
# 10369     0    0   8.6000  2459000.5      59000  20200531.0  0.245579
# 15759     0    0   7.1000  2459000.5      59000  20200531.0  0.070956
# 15787     0    0   7.9000  2459000.5      59000  20200531.0  0.316890
# ...     ...  ...      ...        ...        ...         ...       ...
# 950563    0    0   9.1017  2458842.5      58842  20191225.0  1.001173
# 952472    0    0   6.8441  2458749.5      58749  20190923.0  0.093291
# 954955    0    0  11.9000  2459000.5      59000  20200531.0  0.519137
# 957579    0    0   6.6146  2458893.5      58893  20200214.0  0.614485
# 957706    0    0  10.0720  2459000.5      59000  20200531.0  0.482458
#
#                   a          q          i          om           w          ma  \
# ...

# %%
new_df = df.loc[(df['moid'] <= upper_limit) & (df['moid'] >= lower_limit)]
print('before removing outliers:', len(df))
print('after removing outliers:',len(new_df))
print('outliers:', len(df)-len(new_df))  ##TRIMMING
# Out:
# before removing outliers: 958524
# after removing outliers: 954938
# outliers: 3586

# %%
sns.boxplot(new_df['moid'])
# Out:
# <Axes: >

# %%
new_df = df.copy()
new_df.loc[(new_df['moid']>=upper_limit), 'moid'] = upper_limit
new_df.loc[(new_df['moid']<=lower_limit), 'moid'] = lower_limit  ##CAPPING

# %%
sns.boxplot(new_df['moid'])
# Out:
# <Axes: >

# %%
sns.distplot(new_df['moid'])
# Out:
# C:\Users\deagn\AppData\Local\Temp\ipykernel_3360\3665509624.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(new_df['moid'])
# <Axes: xlabel='moid', ylabel='Density'>

# %% [markdown]
# ## 2) IQR method

# %%
q1 = df['moid'].quantile(0.25)
q3 = df['moid'].quantile(0.75)
iqr = q3-q1

# %%
q1, q3, iqr
# Out:
# (0.984857, 1.58621, 0.6013529999999999)

# %%
upper_limit = q3 + (1.5 * iqr)
lower_limit = q1 - (1.5 * iqr)
lower_limit, upper_limit
# Out:
# (0.08282750000000016, 2.4882394999999997)

# %%
df.loc[(df['moid'] > upper_limit) | (df['moid'] < lower_limit)]
# Out:
#         neo  pha       H      epoch  epoch_mjd   epoch_cal         e  \
# 278       0    0   8.500  2459000.5      59000  20200531.0  0.042520
# 333       0    0   7.700  2459000.5      59000  20200531.0  0.023761
# 587       0    0   8.300  2459000.5      59000  20200531.0  0.147122
# 616       0    0   8.200  2459000.5      59000  20200531.0  0.138967
# 623       0    0   7.200  2459000.5      59000  20200531.0  0.022797
# ...     ...  ...     ...        ...        ...         ...       ...
# 958510    1    0  27.898  2459000.5      59000  20200531.0  0.223160
# 958511    1    0  21.510  2458994.5      58994  20200525.0  0.292102
# 958512    1    0  26.980  2458991.5      58991  20200522.0  0.567768
# 958513    1    0  26.419  2459000.5      59000  20200531.0  0.133246
# 958521    1    1  20.400  2459000.5      59000  20200531.0  0.662446
#
#                a         q          i          om           w          ma  \
# ...

# %%
new_df = df.loc[(df['moid'] <= upper_limit) & (df['moid'] >= lower_limit)]
print('before removing outliers:', len(df))
print('after removing outliers:',len(new_df)) ##TRIMMING
print('outliers:', len(df)-len(new_df))
# Out:
# before removing outliers: 958524
# after removing outliers: 931981
# outliers: 26543

# %%
sns.boxplot(new_df['moid'])
# Out:
# <Axes: >

# %%
sns.distplot(new_df['moid'])
# Out:
# C:\Users\deagn\AppData\Local\Temp\ipykernel_3360\3665509624.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(new_df['moid'])
# <Axes: xlabel='moid', ylabel='Density'>

# %%
new_df = df.copy() ## CAPPING
new_df.loc[(new_df['moid']>upper_limit), 'moid'] = upper_limit
new_df.loc[(new_df['moid']<lower_limit), 'moid'] = lower_limit

# %%
sns.boxplot(new_df['moid'])
# Out:
# <Axes: >

# %%
sns.distplot(new_df['moid'])
# Out:
# C:\Users\deagn\AppData\Local\Temp\ipykernel_3360\3665509624.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(new_df['moid'])
# <Axes: xlabel='moid', ylabel='Density'>

# %% [markdown]
# ## 3) Percentile Method

# %%
upper_limit = df['moid'].quantile(0.99)
lower_limit = df['moid'].quantile(0.01)
print('upper limit:', upper_limit)
print('lower limit:', lower_limit)
# Out:
# upper limit: 3.745150900000003
# lower limit: 0.037004484

# %%
df.loc[(df['moid'] > upper_limit) | (df['moid'] < lower_limit)]
# Out:
#         neo  pha       H      epoch  epoch_mjd   epoch_cal         e  \
# 623       0    0   7.200  2459000.5      59000  20200531.0  0.022797
# 910       0    0   7.900  2459000.5      59000  20200531.0  0.066503
# 1142      0    0   8.300  2459000.5      59000  20200531.0  0.090534
# 1207      0    0   9.000  2459000.5      59000  20200531.0  0.091767
# 1436      0    0   8.200  2459000.5      59000  20200531.0  0.043815
# ...     ...  ...     ...        ...        ...         ...       ...
# 958508    1    0  26.141  2458993.5      58993  20200524.0  0.395881
# 958510    1    0  27.898  2459000.5      59000  20200531.0  0.223160
# 958512    1    0  26.980  2458991.5      58991  20200522.0  0.567768
# 958513    1    0  26.419  2459000.5      59000  20200531.0  0.133246
# 958521    1    1  20.400  2459000.5      59000  20200531.0  0.662446
#
#                a         q          i          om           w          ma  \
# ...

# %%
new_df = df.loc[(df['moid'] <= upper_limit) & (df['moid'] >= lower_limit)]
print('before removing outliers:', len(df))
print('after removing outliers:',len(new_df))  #TRIMMING
print('outliers:', len(df)-len(new_df))
# Out:
# before removing outliers: 958524
# after removing outliers: 939352
# outliers: 19172

# %%
sns.boxplot(new_df['moid'])
# Out:
# <Axes: >

# %%
sns.distplot(new_df['moid'])
# Out:
# C:\Users\deagn\AppData\Local\Temp\ipykernel_3360\3665509624.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(new_df['moid'])
# <Axes: xlabel='moid', ylabel='Density'>

# %%
new_df = df.copy()
new_df.loc[(new_df['moid']>upper_limit), 'moid'] = upper_limit
new_df.loc[(new_df['moid']<lower_limit), 'moid'] = lower_limit #CAPPING

# %%
sns.boxplot(new_df['moid'])
# Out:
# <Axes: >

# %%
sns.distplot(new_df['moid'])
# Out:
# C:\Users\deagn\AppData\Local\Temp\ipykernel_3360\3665509624.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(new_df['moid'])
# <Axes: xlabel='moid', ylabel='Density'>

# %% [markdown]
# tp column outliers removal

# %%
df.describe()
# Out:
#                  neo            pha              H         epoch  \
# count  958524.000000  958524.000000  958524.000000  9.585240e+05
# mean        0.023886       0.002155      16.906411  2.458869e+06
# std         0.152693       0.046376       1.784546  7.016716e+02
# min         0.000000       0.000000      -1.100000  2.425052e+06
# 25%         0.000000       0.000000      16.100000  2.459000e+06
# 50%         0.000000       0.000000      16.900000  2.459000e+06
# 75%         0.000000       0.000000      17.700000  2.459000e+06
# max         1.000000       1.000000      33.200000  2.459000e+06
#
#            epoch_mjd     epoch_cal              e              a  \
# count  958524.000000  9.585240e+05  958524.000000  958524.000000
# mean    58868.781950  2.019693e+07       0.156116       2.902143
# std       701.671573  1.930354e+04       0.092643      39.719503
# min     25051.000000  1.927062e+07       0.000000  -14702.447872
# ...

# %%
sns.distplot(df['tp'])
# Out:
# C:\Users\deagn\AppData\Local\Temp\ipykernel_3360\2942128133.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['tp'])
# <Axes: xlabel='tp', ylabel='Density'>

# %%
sns.boxplot(df['tp'])
# Out:
# <Axes: >

# %% [markdown]
# 1.Zscore

# %%
upper_limit = df['tp'].mean() + 3 * df['tp'].std()
lower_limit = df['tp'].mean() - 3 * df['tp'].std()
# Filtering out the outliers
filtered_df = df[(df['tp'] >= lower_limit) & (df['tp'] <= upper_limit)]
# Displaying the upper and lower limits
print('Upper limit:', upper_limit)
print('Lower limit:', lower_limit)
# Out:
# Upper limit: 2463597.7553518442
# Lower limit: 2454114.718100923

# %%
df.loc[(df['tp'] > upper_limit) | (df['tp'] < lower_limit)]
# Out:
#         neo  pha       H      epoch  epoch_mjd   epoch_cal         e  \
# 2059      0    0   5.800  2459000.5      59000  20200531.0  0.378784
# 2339      1    1  20.200  2453228.5      53228  20040811.0  0.449884
# 5144      0    0   7.100  2459000.5      59000  20200531.0  0.569257
# 6488      1    1  19.200  2452464.5      52464  20020709.0  0.605297
# 7065      0    0   9.600  2459000.5      59000  20200531.0  0.517555
# ...     ...  ...     ...        ...        ...         ...       ...
# 958517    0    0  16.280  2437204.5      37204  19600927.0  0.219023
# 958518    0    0  16.827  2437204.5      37204  19600927.0  0.238416
# 958519    0    0  17.135  2437203.5      37203  19600926.0  0.185919
# 958522    0    0  18.071  2441956.5      41956  19731001.0  0.202053
# 958523    0    0  18.060  2443429.5      43429  19771013.0  0.258348
#
#                 a          q          i          om           w          ma  \
# ...

# %%
new_df = df.loc[(df['tp'] <= upper_limit) & (df['tp'] >= lower_limit)]
print('Before removing outliers:', len(df))
print('After removing outliers:', len(new_df))
print('Outliers removed:', len(df) - len(new_df))
# Out:
# Before removing outliers: 958524
# After removing outliers: 950411
# Outliers removed: 8113

# %%
sns.boxplot(new_df['tp'])
# Out:
# <Axes: >

# %%
new_df = df.copy()
new_df.loc[(new_df['tp']>=upper_limit), 'tp'] = upper_limit
new_df.loc[(new_df['tp']<=lower_limit), 'tp'] = lower_limit  ##CAPPING

# %%
sns.boxplot(new_df['tp'])
# Out:
# <Axes: >

# %%
sns.distplot(new_df['tp'])
# Out:
# C:\Users\deagn\AppData\Local\Temp\ipykernel_3360\1958082692.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(new_df['tp'])
# <Axes: xlabel='tp', ylabel='Density'>

# %% [markdown]
# IQR Method

# %%
q1 = df['tp'].quantile(0.25)
q3 = df['tp'].quantile(0.75)
iqr = q3-q1

# %%
q1, q3, iqr
# Out:
# (2458560.322334967, 2459361.285088151, 800.9627531841397)

# %%
upper_limit = q3 + (1.5 * iqr)
lower_limit = q1 - (1.5 * iqr)
lower_limit, upper_limit
# Out:
# (2457358.878205191, 2460562.7292179274)

# %%
df.loc[(df['tp'] > upper_limit) | (df['tp'] < lower_limit)]
# Out:
#         neo  pha       H      epoch  epoch_mjd   epoch_cal         e  \
# 623       0    0   7.200  2459000.5      59000  20200531.0  0.022797
# 1646      0    0  10.500  2459000.5      59000  20200531.0  0.021154
# 2059      0    0   5.800  2459000.5      59000  20200531.0  0.378784
# 2061      1    0  17.100  2455926.5      55926  20111231.0  0.182717
# 2339      1    1  20.200  2453228.5      53228  20040811.0  0.449884
# ...     ...  ...     ...        ...        ...         ...       ...
# 958517    0    0  16.280  2437204.5      37204  19600927.0  0.219023
# 958518    0    0  16.827  2437204.5      37204  19600927.0  0.238416
# 958519    0    0  17.135  2437203.5      37203  19600926.0  0.185919
# 958522    0    0  18.071  2441956.5      41956  19731001.0  0.202053
# 958523    0    0  18.060  2443429.5      43429  19771013.0  0.258348
#
#                 a         q          i          om           w          ma  \
# ...

# %%
new_df = df.loc[(df['tp'] <= upper_limit) & (df['tp'] >= lower_limit)]
print('before removing outliers:', len(df))
print('after removing outliers:',len(new_df)) ##TRIMMING
print('outliers:', len(df)-len(new_df))
# Out:
# before removing outliers: 958524
# after removing outliers: 922711
# outliers: 35813

# %%
sns.boxplot(new_df['tp'])
# Out:
# <Axes: >

# %%
sns.distplot(new_df['tp'])
# Out:
# C:\Users\deagn\AppData\Local\Temp\ipykernel_3360\1958082692.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(new_df['tp'])
# <Axes: xlabel='tp', ylabel='Density'>

# %%
new_df = df.copy() ## CAPPING
new_df.loc[(new_df['tp']>upper_limit), 'tp'] = upper_limit
new_df.loc[(new_df['tp']<lower_limit), 'tp'] = lower_limit

# %%
sns.boxplot(new_df['tp'])
# Out:
# <Axes: >

# %%
sns.distplot(new_df['tp'])
# Out:
# C:\Users\deagn\AppData\Local\Temp\ipykernel_3360\1958082692.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(new_df['tp'])
# <Axes: xlabel='tp', ylabel='Density'>

# %% [markdown]
# Percentile Method

# %%
upper_limit = df['tp'].quantile(0.99)
lower_limit = df['tp'].quantile(0.01)
print('upper limit:', upper_limit)
print('lower limit:', lower_limit)
# Out:
# upper limit: 2459965.6029463443
# lower limit: 2454715.2251870045

# %%
df.loc[(df['tp'] > upper_limit) | (df['tp'] < lower_limit)]
# Out:
#         neo  pha       H      epoch  epoch_mjd   epoch_cal         e  \
# 152       0    0   7.600  2459000.5      59000  20200531.0  0.140283
# 278       0    0   8.500  2459000.5      59000  20200531.0  0.042520
# 399       0    0  10.500  2459000.5      59000  20200531.0  0.116292
# 544       0    0   8.800  2459000.5      59000  20200531.0  0.169858
# 587       0    0   8.300  2459000.5      59000  20200531.0  0.147122
# ...     ...  ...     ...        ...        ...         ...       ...
# 958517    0    0  16.280  2437204.5      37204  19600927.0  0.219023
# 958518    0    0  16.827  2437204.5      37204  19600927.0  0.238416
# 958519    0    0  17.135  2437203.5      37203  19600926.0  0.185919
# 958522    0    0  18.071  2441956.5      41956  19731001.0  0.202053
# 958523    0    0  18.060  2443429.5      43429  19771013.0  0.258348
#
#                a         q          i          om           w          ma  \
# ...

# %%
new_df = df.loc[(df['tp'] <= upper_limit) & (df['tp'] >= lower_limit)]
print('before removing outliers:', len(df))
print('after removing outliers:',len(new_df))  #TRIMMING
print('outliers:', len(df)-len(new_df))
# Out:
# before removing outliers: 958524
# after removing outliers: 939352
# outliers: 19172

# %%
sns.boxplot(new_df['tp'])
# Out:
# <Axes: >

# %%
sns.distplot(new_df['tp'])
# Out:
# C:\Users\deagn\AppData\Local\Temp\ipykernel_3360\1958082692.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(new_df['tp'])
# <Axes: xlabel='tp', ylabel='Density'>

# %%
new_df = df.copy()
new_df.loc[(new_df['tp']>upper_limit), 'tp'] = upper_limit
new_df.loc[(new_df['tp']<lower_limit), 'tp'] = lower_limit #CAPPING

# %%
sns.boxplot(new_df['tp'])
# Out:
# <Axes: >

# %%
sns.distplot(new_df['tp'])
# Out:
# C:\Users\deagn\AppData\Local\Temp\ipykernel_3360\1958082692.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(new_df['tp'])
# <Axes: xlabel='tp', ylabel='Density'>

# %% [markdown]
# Outlier Removal rms

# %%
df.describe()
# Out:
#                  neo            pha              H         epoch  \
# count  958524.000000  958524.000000  958524.000000  9.585240e+05
# mean        0.023886       0.002155      16.906411  2.458869e+06
# std         0.152693       0.046376       1.784546  7.016716e+02
# min         0.000000       0.000000      -1.100000  2.425052e+06
# 25%         0.000000       0.000000      16.100000  2.459000e+06
# 50%         0.000000       0.000000      16.900000  2.459000e+06
# 75%         0.000000       0.000000      17.700000  2.459000e+06
# max         1.000000       1.000000      33.200000  2.459000e+06
#
#            epoch_mjd     epoch_cal              e              a  \
# count  958524.000000  9.585240e+05  958524.000000  958524.000000
# mean    58868.781950  2.019693e+07       0.156116       2.902143
# std       701.671573  1.930354e+04       0.092643      39.719503
# min     25051.000000  1.927062e+07       0.000000  -14702.447872
# ...

# %%
sns.distplot(df['rms'])
# Out:
# C:\Users\deagn\AppData\Local\Temp\ipykernel_3360\917870107.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['rms'])
# <Axes: xlabel='rms', ylabel='Density'>

# %%
sns.boxplot(df['rms'])
# Out:
# <Axes: >

# %% [markdown]
# Zscore

# %%
upper_limit = df['rms'].mean() + 3*df['rms'].std()
lower_limit = df['rms'].mean() - 3*df['rms'].std()
print('upper limit:', upper_limit)
print('lower limit:', lower_limit)
# Out:
# upper limit: 8.798243536120397
# lower limit: -7.675937917853824

# %%
df.loc[(df['rms'] > upper_limit) | (df['rms'] < lower_limit)]
# Out:
#         neo  pha       H      epoch  epoch_mjd   epoch_cal         e  \
# 770675    0    0  18.688  2459000.5      59000  20200531.0  0.124201
# 933486    0    0  18.523  2458093.5      58093  20171206.0  0.397476
# 957691    1    0  27.846  2459000.5      59000  20200531.0  0.243700
#
#                a         q         i          om           w          ma  \
# 770675  2.154143  1.886597  4.526916   29.682104  215.641089  288.819813
# 933486  3.102112  1.869096  2.033340   40.780149   79.473509  334.471943
# 957691  1.155830  0.874154  3.358000  158.902000  284.987000  123.433000
#
#               ad         n            tp        tp_cal          per     per_y  \
# 770675  2.421689  0.311740  2.459229e+06  2.021011e+07  1154.809229  3.161695
# 933486  4.335127  0.180392  2.458235e+06  2.018043e+07  1995.651028  5.463795
# 957691  1.437506  0.793164  2.458845e+06  2.019123e+07   453.878249  1.242651
#
#             moid     moid_ld OrbitType       rms
# ...

# %%
new_df = df.loc[(df['rms'] <= upper_limit) & (df['rms'] >= lower_limit)]
print('before removing outliers:', len(df))
print('after removing outliers:',len(new_df))
print('outliers:', len(df)-len(new_df))  ##TRIMMING
# Out:
# before removing outliers: 958524
# after removing outliers: 958521
# outliers: 3

# %%
sns.boxplot(new_df['rms'])
# Out:
# <Axes: >

# %%
new_df = df.copy()
new_df.loc[(new_df['rms']>=upper_limit), 'rms'] = upper_limit
new_df.loc[(new_df['rms']<=lower_limit), 'rms'] = lower_limit  ##CAPPING

# %%
sns.boxplot(new_df['rms'])
# Out:
# <Axes: >

# %%
sns.distplot(new_df['rms'])
# Out:
# C:\Users\deagn\AppData\Local\Temp\ipykernel_3360\1093232120.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(new_df['rms'])
# <Axes: xlabel='rms', ylabel='Density'>

# %% [markdown]
# IQR method

# %%
q1 = df['rms'].quantile(0.25)
q3 = df['rms'].quantile(0.75)
iqr = q3-q1

# %%
q1, q3, iqr
# Out:
# (0.51804, 0.6139225, 0.09588250000000009)

# %%
upper_limit = q3 + (1.5 * iqr)
lower_limit = q1 - (1.5 * iqr)
lower_limit, upper_limit
# Out:
# (0.3742162499999998, 0.7577462500000002)

# %%
df.loc[(df['rms'] > upper_limit) | (df['rms'] < lower_limit)]
# Out:
#         neo  pha       H      epoch  epoch_mjd   epoch_cal         e  \
# 1         0    0   4.200  2459000.5      59000  20200531.0  0.229972
# 2         0    0   5.330  2459000.5      59000  20200531.0  0.256936
# 15        0    0   5.900  2459000.5      59000  20200531.0  0.133531
# 54        0    0   7.700  2459000.5      59000  20200531.0  0.143246
# 80        0    0   8.600  2459000.5      59000  20200531.0  0.210847
# ...     ...  ...     ...        ...        ...         ...       ...
# 958517    0    0  16.280  2437204.5      37204  19600927.0  0.219023
# 958518    0    0  16.827  2437204.5      37204  19600927.0  0.238416
# 958519    0    0  17.135  2437203.5      37203  19600926.0  0.185919
# 958522    0    0  18.071  2441956.5      41956  19731001.0  0.202053
# 958523    0    0  18.060  2443429.5      43429  19771013.0  0.258348
#
#                a         q          i          om           w          ma  \
# ...

# %%
new_df = df.loc[(df['rms'] <= upper_limit) & (df['rms'] >= lower_limit)]
print('before removing outliers:', len(df))
print('after removing outliers:',len(new_df)) ##TRIMMING
print('outliers:', len(df)-len(new_df))
# Out:
# before removing outliers: 958524
# after removing outliers: 893736
# outliers: 64788

# %%
sns.boxplot(new_df['rms'])
# Out:
# <Axes: >

# %%
sns.distplot(new_df['rms'])
# Out:
# C:\Users\deagn\AppData\Local\Temp\ipykernel_3360\1093232120.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(new_df['rms'])
# <Axes: xlabel='rms', ylabel='Density'>

# %%
new_df = df.copy() ## CAPPING
new_df.loc[(new_df['rms']>upper_limit), 'rms'] = upper_limit
new_df.loc[(new_df['rms']<lower_limit), 'rms'] = lower_limit

# %%
sns.boxplot(new_df['rms'])
# Out:
# <Axes: >

# %%
sns.distplot(new_df['rms'])
# Out:
# C:\Users\deagn\AppData\Local\Temp\ipykernel_3360\1093232120.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(new_df['rms'])
# <Axes: xlabel='rms', ylabel='Density'>

# %% [markdown]
# Percentile Method

# %%
upper_limit = df['rms'].quantile(0.99)
lower_limit = df['rms'].quantile(0.01)
print('upper limit:', upper_limit)
print('lower limit:', lower_limit)
# Out:
# upper limit: 0.7799377000000002
# lower limit: 0.20302

# %%
df.loc[(df['rms'] > upper_limit) | (df['rms'] < lower_limit)]
# Out:
#         neo  pha       H      epoch  epoch_mjd   epoch_cal         e  \
# 15759     0    0   7.100  2459000.5      59000  20200531.0  0.070956
# 24977     0    0   7.500  2459000.5      59000  20200531.0  0.048767
# 45801     0    0   8.000  2459000.5      59000  20200531.0  0.014536
# 66777     0    0  15.400  2459000.5      59000  20200531.0  0.116331
# 69986     0    0   7.100  2459000.5      59000  20200531.0  0.023678
# ...     ...  ...     ...        ...        ...         ...       ...
# 958500    0    0  18.500  2458980.5      58980  20200511.0  0.387112
# 958509    1    0  24.081  2458991.5      58991  20200522.0  0.326254
# 958514    0    0  15.576  2437204.5      37204  19600927.0  0.266788
# 958516    0    0  17.393  2437203.5      37203  19600926.0  0.200505
# 958517    0    0  16.280  2437204.5      37204  19600927.0  0.219023
#
#                 a          q          i          om           w          ma  \
# ...

# %%
new_df = df.loc[(df['rms'] <= upper_limit) & (df['rms'] >= lower_limit)]
print('before removing outliers:', len(df))
print('after removing outliers:',len(new_df))  #TRIMMING
print('outliers:', len(df)-len(new_df))
# Out:
# before removing outliers: 958524
# after removing outliers: 939353
# outliers: 19171

# %%
sns.boxplot(new_df['rms'])
# Out:
# <Axes: >

# %%
sns.distplot(new_df['rms'])
# Out:
# C:\Users\deagn\AppData\Local\Temp\ipykernel_3360\1093232120.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(new_df['rms'])
# <Axes: xlabel='rms', ylabel='Density'>

# %%
new_df = df.copy()
new_df.loc[(new_df['rms']>upper_limit), 'rms'] = upper_limit
new_df.loc[(new_df['rms']<lower_limit), 'rms'] = lower_limit #CAPPING

# %%
sns.boxplot(new_df['rms'])
# Out:
# <Axes: >

# %%
sns.distplot(new_df['rms'])
# Out:
# C:\Users\deagn\AppData\Local\Temp\ipykernel_3360\1093232120.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(new_df['rms'])
# <Axes: xlabel='rms', ylabel='Density'>

# %%
df.describe()
# Out:
#                  neo            pha              H         epoch  \
# count  958524.000000  958524.000000  958524.000000  9.585240e+05
# mean        0.023886       0.002155      16.906411  2.458869e+06
# std         0.152693       0.046376       1.784546  7.016716e+02
# min         0.000000       0.000000      -1.100000  2.425052e+06
# 25%         0.000000       0.000000      16.100000  2.459000e+06
# 50%         0.000000       0.000000      16.900000  2.459000e+06
# 75%         0.000000       0.000000      17.700000  2.459000e+06
# max         1.000000       1.000000      33.200000  2.459000e+06
#
#            epoch_mjd     epoch_cal              e              a  \
# count  958524.000000  9.585240e+05  958524.000000  958524.000000
# mean    58868.781950  2.019693e+07       0.156116       2.902143
# std       701.671573  1.930354e+04       0.092643      39.719503
# min     25051.000000  1.927062e+07       0.000000  -14702.447872
# ...

# %% [markdown]
# outliers remove epoch

# %%
sns.distplot(df['epoch'])
# Out:
# C:\Users\deagn\AppData\Local\Temp\ipykernel_22176\4101430889.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['epoch'])
# <Axes: xlabel='epoch', ylabel='Density'>

# %%
sns.boxplot(df['epoch'])
# Out:
# <Axes: >

# %% [markdown]
# zscore

# %%
upper_limit = df['epoch'].mean() + 3*df['epoch'].std()
lower_limit = df['epoch'].mean() - 3*df['epoch'].std()
print('upper limit:', upper_limit)
print('lower limit:', lower_limit)
# Out:
# upper limit: 2460974.2966694483
# lower limit: 2456764.267230882

# %%
df.loc[(df['epoch'] > upper_limit) | (df['epoch'] < lower_limit)]
# Out:
#         neo  pha       H      epoch  epoch_mjd   epoch_cal         e  \
# 2061      1    0  17.100  2455926.5      55926  20111231.0  0.182717
# 2339      1    1  20.200  2453228.5      53228  20040811.0  0.449884
# 3360      1    1  19.030  2455844.5      55844  20111010.0  0.322752
# 4033      1    1  18.400  2455202.5      55202  20100106.0  0.443943
# 6488      1    1  19.200  2452464.5      52464  20020709.0  0.605297
# ...     ...  ...     ...        ...        ...         ...       ...
# 958517    0    0  16.280  2437204.5      37204  19600927.0  0.219023
# 958518    0    0  16.827  2437204.5      37204  19600927.0  0.238416
# 958519    0    0  17.135  2437203.5      37203  19600926.0  0.185919
# 958522    0    0  18.071  2441956.5      41956  19731001.0  0.202053
# 958523    0    0  18.060  2443429.5      43429  19771013.0  0.258348
#
#                a         q          i          om           w          ma  \
# ...

# %%
new_df = df.loc[(df['epoch'] <= upper_limit) & (df['epoch'] >= lower_limit)]
print('before removing outliers:', len(df))
print('after removing outliers:',len(new_df))
print('outliers:', len(df)-len(new_df))  ##TRIMMING
# Out:
# before removing outliers: 958524
# after removing outliers: 932856
# outliers: 25668

# %%
sns.boxplot(new_df['epoch'])
# Out:
# <Axes: >

# %%
new_df = df.copy()
new_df.loc[(new_df['epoch']>=upper_limit), 'epoch'] = upper_limit
new_df.loc[(new_df['epoch']<=lower_limit), 'epoch'] = lower_limit  ##CAPPING

# %%
sns.boxplot(new_df['epoch'])
# Out:
# <Axes: >

# %%
sns.distplot(new_df['epoch'])
# Out:
# C:\Users\deagn\AppData\Local\Temp\ipykernel_22176\546855594.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(new_df['epoch'])
# <Axes: xlabel='epoch', ylabel='Density'>

# %% [markdown]
# IQR method

# %%
q1 = df['epoch'].quantile(0.25)
q3 = df['epoch'].quantile(0.75)
iqr = q3-q1

# %%
q1, q3, iqr
# Out:
# (2459000.5, 2459000.5, 0.0)

# %%
upper_limit = q3 + (1.5 * iqr)
lower_limit = q1 - (1.5 * iqr)
lower_limit, upper_limit
# Out:
# (2459000.5, 2459000.5)

# %%
df.loc[(df['epoch'] > upper_limit) | (df['epoch'] < lower_limit)]
# Out:
#         neo  pha       H      epoch  epoch_mjd   epoch_cal         e  \
# 0         0    0   3.400  2458600.5      58600  20190427.0  0.076009
# 3         0    0   3.000  2458600.5      58600  20190427.0  0.088721
# 2061      1    0  17.100  2455926.5      55926  20111231.0  0.182717
# 2339      1    1  20.200  2453228.5      53228  20040811.0  0.449884
# 3360      1    1  19.030  2455844.5      55844  20111010.0  0.322752
# ...     ...  ...     ...        ...        ...         ...       ...
# 958517    0    0  16.280  2437204.5      37204  19600927.0  0.219023
# 958518    0    0  16.827  2437204.5      37204  19600927.0  0.238416
# 958519    0    0  17.135  2437203.5      37203  19600926.0  0.185919
# 958522    0    0  18.071  2441956.5      41956  19731001.0  0.202053
# 958523    0    0  18.060  2443429.5      43429  19771013.0  0.258348
#
#                a         q          i          om           w          ma  \
# ...

# %%
new_df = df.loc[(df['epoch'] <= upper_limit) & (df['epoch'] >= lower_limit)]
print('before removing outliers:', len(df))
print('after removing outliers:',len(new_df)) ##TRIMMING
print('outliers:', len(df)-len(new_df))
# Out:
# before removing outliers: 958524
# after removing outliers: 909386
# outliers: 49138

# %%
sns.distplot(new_df['epoch'])
# Out:
# C:\Users\deagn\AppData\Local\Temp\ipykernel_22176\546855594.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(new_df['epoch'])
# c:\Users\deagn\anaconda3\Lib\site-packages\seaborn\distributions.py:2511: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   kdeplot(**{axis: a}, ax=ax, color=kde_color, **kde_kws)
# <Axes: xlabel='epoch', ylabel='Density'>

# %%
new_df = df.copy() ## CAPPING
new_df.loc[(new_df['epoch']>upper_limit), 'epoch'] = upper_limit
new_df.loc[(new_df['epoch']<lower_limit), 'epoch'] = lower_limit

# %%
sns.boxplot(new_df['epoch'])
# Out:
# <Axes: >

# %%
sns.distplot(new_df['epoch'])
# Out:
# C:\Users\deagn\AppData\Local\Temp\ipykernel_22176\546855594.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(new_df['epoch'])
# c:\Users\deagn\anaconda3\Lib\site-packages\seaborn\distributions.py:2511: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   kdeplot(**{axis: a}, ax=ax, color=kde_color, **kde_kws)
# <Axes: xlabel='epoch', ylabel='Density'>

# %% [markdown]
# Percentile Method

# %%
upper_limit = df['epoch'].quantile(0.99)
lower_limit = df['epoch'].quantile(0.01)
print('upper limit:', upper_limit)
print('lower limit:', lower_limit)
# Out:
# upper limit: 2459000.5
# lower limit: 2455213.5

# %%
df.loc[(df['epoch'] > upper_limit) | (df['epoch'] < lower_limit)]
# Out:
#         neo  pha       H      epoch  epoch_mjd   epoch_cal         e  \
# 2339      1    1  20.200  2453228.5      53228  20040811.0  0.449884
# 4033      1    1  18.400  2455202.5      55202  20100106.0  0.443943
# 6488      1    1  19.200  2452464.5      52464  20020709.0  0.605297
# 54508     1    0  22.700  2452656.5      52656  20030117.0  0.229915
# 85769     1    0  20.500  2453837.5      53837  20060412.0  0.344939
# ...     ...  ...     ...        ...        ...         ...       ...
# 958517    0    0  16.280  2437204.5      37204  19600927.0  0.219023
# 958518    0    0  16.827  2437204.5      37204  19600927.0  0.238416
# 958519    0    0  17.135  2437203.5      37203  19600926.0  0.185919
# 958522    0    0  18.071  2441956.5      41956  19731001.0  0.202053
# 958523    0    0  18.060  2443429.5      43429  19771013.0  0.258348
#
#                a         q          i          om           w          ma  \
# ...

# %%
new_df = df.loc[(df['epoch'] <= upper_limit) & (df['epoch'] >= lower_limit)]
print('before removing outliers:', len(df))
print('after removing outliers:',len(new_df))  #TRIMMING
print('outliers:', len(df)-len(new_df))
# Out:
# before removing outliers: 958524
# after removing outliers: 948947
# outliers: 9577

# %%
sns.boxplot(new_df['epoch'])
# Out:
# <Axes: >

# %%
sns.distplot(new_df['epoch'])
# Out:
# C:\Users\deagn\AppData\Local\Temp\ipykernel_22176\546855594.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(new_df['epoch'])
# <Axes: xlabel='epoch', ylabel='Density'>

# %%
new_df = df.copy()
new_df.loc[(new_df['epoch']>upper_limit), 'epoch'] = upper_limit
new_df.loc[(new_df['epoch']<lower_limit), 'epoch'] = lower_limit #CAPPING

# %%
sns.boxplot(new_df['epoch'])
# Out:
# <Axes: >

# %%
sns.distplot(new_df['epoch'])
# Out:
# C:\Users\deagn\AppData\Local\Temp\ipykernel_22176\546855594.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(new_df['epoch'])
# <Axes: xlabel='epoch', ylabel='Density'>

# %%
df.describe()
# Out:
#                  neo            pha              H         epoch  \
# count  958524.000000  958524.000000  958524.000000  9.585240e+05
# mean        0.023886       0.002155      16.906411  2.458869e+06
# std         0.152693       0.046376       1.784546  7.016716e+02
# min         0.000000       0.000000      -1.100000  2.425052e+06
# 25%         0.000000       0.000000      16.100000  2.459000e+06
# 50%         0.000000       0.000000      16.900000  2.459000e+06
# 75%         0.000000       0.000000      17.700000  2.459000e+06
# max         1.000000       1.000000      33.200000  2.459000e+06
#
#            epoch_mjd     epoch_cal              e              a  \
# count  958524.000000  9.585240e+05  958524.000000  958524.000000
# mean    58868.781950  2.019693e+07       0.156116       2.902143
# std       701.671573  1.930354e+04       0.092643      39.719503
# min     25051.000000  1.927062e+07       0.000000  -14702.447872
# ...

# %% [markdown]
# outlier removal H

# %%
sns.distplot(df['H'])
# Out:
# C:\Users\deagn\AppData\Local\Temp\ipykernel_22176\2835799590.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['H'])
# <Axes: xlabel='H', ylabel='Density'>

# %%
sns.boxplot(df['H'])
# Out:
# <Axes: >

# %% [markdown]
# ZSCORE

# %%
upper_limit = df['H'].mean() + 3*df['H'].std()
lower_limit = df['H'].mean() - 3*df['H'].std()
print('upper limit:', upper_limit)
print('lower limit:', lower_limit)
# Out:
# upper limit: 22.260049765762687
# lower limit: 11.552772689635574

# %%
df.loc[(df['H'] > upper_limit) | (df['H'] < lower_limit)]
# Out:
#         neo  pha       H      epoch  epoch_mjd   epoch_cal         e  \
# 0         0    0   3.400  2458600.5      58600  20190427.0  0.076009
# 1         0    0   4.200  2459000.5      59000  20200531.0  0.229972
# 2         0    0   5.330  2459000.5      59000  20200531.0  0.256936
# 3         0    0   3.000  2458600.5      58600  20190427.0  0.088721
# 4         0    0   6.900  2459000.5      59000  20200531.0  0.190913
# ...     ...  ...     ...        ...        ...         ...       ...
# 958508    1    0  26.141  2458993.5      58993  20200524.0  0.395881
# 958509    1    0  24.081  2458991.5      58991  20200522.0  0.326254
# 958510    1    0  27.898  2459000.5      59000  20200531.0  0.223160
# 958512    1    0  26.980  2458991.5      58991  20200522.0  0.567768
# 958513    1    0  26.419  2459000.5      59000  20200531.0  0.133246
#
#                a         q          i          om           w          ma  \
# ...

# %%
new_df = df.loc[(df['H'] <= upper_limit) & (df['H'] >= lower_limit)]
print('before removing outliers:', len(df))
print('after removing outliers:',len(new_df))
print('outliers:', len(df)-len(new_df))  ##TRIMMING
# Out:
# before removing outliers: 958524
# after removing outliers: 939307
# outliers: 19217

# %%
new_df = df.copy()
new_df.loc[(new_df['H']>=upper_limit), 'H'] = upper_limit
new_df.loc[(new_df['H']<=lower_limit), 'H'] = lower_limit  ##CAPPING

# %%
sns.boxplot(new_df['H'])
# Out:
# <Axes: >

# %%
sns.distplot(new_df['H'])
# Out:
# C:\Users\deagn\AppData\Local\Temp\ipykernel_22176\3144871268.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(new_df['H'])
# <Axes: xlabel='H', ylabel='Density'>

# %% [markdown]
# IQR Method

# %%
q1 = df['H'].quantile(0.25)
q3 = df['H'].quantile(0.75)
iqr = q3-q1

# %%
q1, q3, iqr
# Out:
# (16.1, 17.7, 1.5999999999999979)

# %%
upper_limit = q3 + (1.5 * iqr)
lower_limit = q1 - (1.5 * iqr)
lower_limit, upper_limit
# Out:
# (13.700000000000005, 20.099999999999994)

# %%
df.loc[(df['H'] > upper_limit) | (df['H'] < lower_limit)]
# Out:
#         neo  pha       H      epoch  epoch_mjd   epoch_cal         e  \
# 0         0    0   3.400  2458600.5      58600  20190427.0  0.076009
# 1         0    0   4.200  2459000.5      59000  20200531.0  0.229972
# 2         0    0   5.330  2459000.5      59000  20200531.0  0.256936
# 3         0    0   3.000  2458600.5      58600  20190427.0  0.088721
# 4         0    0   6.900  2459000.5      59000  20200531.0  0.190913
# ...     ...  ...     ...        ...        ...         ...       ...
# 958510    1    0  27.898  2459000.5      59000  20200531.0  0.223160
# 958511    1    0  21.510  2458994.5      58994  20200525.0  0.292102
# 958512    1    0  26.980  2458991.5      58991  20200522.0  0.567768
# 958513    1    0  26.419  2459000.5      59000  20200531.0  0.133246
# 958521    1    1  20.400  2459000.5      59000  20200531.0  0.662446
#
#                a         q          i          om           w          ma  \
# ...

# %%
new_df = df.loc[(df['H'] <= upper_limit) & (df['H'] >= lower_limit)]
print('before removing outliers:', len(df))
print('after removing outliers:',len(new_df)) ##TRIMMING
print('outliers:', len(df)-len(new_df))
# Out:
# before removing outliers: 958524
# after removing outliers: 911101
# outliers: 47423

# %%
sns.distplot(new_df['H'])
# Out:
# C:\Users\deagn\AppData\Local\Temp\ipykernel_22176\3144871268.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(new_df['H'])
# <Axes: xlabel='H', ylabel='Density'>

# %%
new_df = df.copy() ## CAPPING
new_df.loc[(new_df['H']>upper_limit), 'H'] = upper_limit
new_df.loc[(new_df['H']<lower_limit), 'H'] = lower_limit

# %%
sns.boxplot(new_df['H'])
# Out:
# <Axes: >

# %%
sns.distplot(new_df['H'])
# Out:
# C:\Users\deagn\AppData\Local\Temp\ipykernel_22176\3144871268.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(new_df['H'])
# <Axes: xlabel='H', ylabel='Density'>

# %% [markdown]
# Percentile method

# %%
upper_limit = df['H'].quantile(0.99)
lower_limit = df['H'].quantile(0.01)
print('upper limit:', upper_limit)
print('lower limit:', lower_limit)
# Out:
# upper limit: 23.8
# lower limit: 12.6

# %%
df.loc[(df['H'] > upper_limit) | (df['H'] < lower_limit)]
# Out:
#         neo  pha       H      epoch  epoch_mjd   epoch_cal         e  \
# 0         0    0   3.400  2458600.5      58600  20190427.0  0.076009
# 1         0    0   4.200  2459000.5      59000  20200531.0  0.229972
# 2         0    0   5.330  2459000.5      59000  20200531.0  0.256936
# 3         0    0   3.000  2458600.5      58600  20190427.0  0.088721
# 4         0    0   6.900  2459000.5      59000  20200531.0  0.190913
# ...     ...  ...     ...        ...        ...         ...       ...
# 958508    1    0  26.141  2458993.5      58993  20200524.0  0.395881
# 958509    1    0  24.081  2458991.5      58991  20200522.0  0.326254
# 958510    1    0  27.898  2459000.5      59000  20200531.0  0.223160
# 958512    1    0  26.980  2458991.5      58991  20200522.0  0.567768
# 958513    1    0  26.419  2459000.5      59000  20200531.0  0.133246
#
#                a         q          i          om           w          ma  \
# ...

# %%
new_df = df.loc[(df['H'] <= upper_limit) & (df['H'] >= lower_limit)]
print('before removing outliers:', len(df))
print('after removing outliers:',len(new_df))  #TRIMMING
print('outliers:', len(df)-len(new_df))
# Out:
# before removing outliers: 958524
# after removing outliers: 940092
# outliers: 18432

# %%
sns.distplot(new_df['H'])
# Out:
# C:\Users\deagn\AppData\Local\Temp\ipykernel_22176\3144871268.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(new_df['H'])
# <Axes: xlabel='H', ylabel='Density'>

# %%
new_df = df.copy()
new_df.loc[(new_df['H']>upper_limit), 'H'] = upper_limit
new_df.loc[(new_df['H']<lower_limit), 'H'] = lower_limit #CAPPING

# %%
sns.boxplot(new_df['H'])
# Out:
# <Axes: >

# %%
sns.distplot(new_df['H'])
# Out:
# C:\Users\deagn\AppData\Local\Temp\ipykernel_22176\3144871268.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(new_df['H'])
# <Axes: xlabel='H', ylabel='Density'>

# %% [markdown]
# outlier removal(e)

# %%
df.describe()
# Out:
#                  neo            pha              H         epoch  \
# count  958524.000000  958524.000000  958524.000000  9.585240e+05
# mean        0.023886       0.002155      16.906411  2.458869e+06
# std         0.152693       0.046376       1.784546  7.016716e+02
# min         0.000000       0.000000      -1.100000  2.425052e+06
# 25%         0.000000       0.000000      16.100000  2.459000e+06
# 50%         0.000000       0.000000      16.900000  2.459000e+06
# 75%         0.000000       0.000000      17.700000  2.459000e+06
# max         1.000000       1.000000      33.200000  2.459000e+06
#
#            epoch_mjd     epoch_cal              e              a  \
# count  958524.000000  9.585240e+05  958524.000000  958524.000000
# mean    58868.781950  2.019693e+07       0.156116       2.902143
# std       701.671573  1.930354e+04       0.092643      39.719503
# min     25051.000000  1.927062e+07       0.000000  -14702.447872
# ...

# %%
sns.distplot(df['e'])
# Out:
# C:\Users\deagn\AppData\Local\Temp\ipykernel_8964\3355162531.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['e'])
# <Axes: xlabel='e', ylabel='Density'>

# %%
sns.boxplot(df['e'])
# Out:
# <Axes: >

# %% [markdown]
# zscore

# %%
upper_limit = df['e'].mean() + 3*df['e'].std()
lower_limit = df['e'].mean() - 3*df['e'].std()
print('upper limit:', upper_limit)
print('lower limit:', lower_limit)
# Out:
# upper limit: 0.43404421426760925
# lower limit: -0.12181160137014874

# %%
df.loc[(df['e'] > upper_limit) | (df['e'] < lower_limit)]
# Out:
#         neo  pha       H      epoch  epoch_mjd   epoch_cal         e  \
# 718       1    0  15.400  2459000.5      59000  20200531.0  0.546558
# 886       1    0  13.800  2459000.5      59000  20200531.0  0.570332
# 943       0    0  10.700  2459000.5      59000  20200531.0  0.660560
# 1008      0    0  13.900  2459000.5      59000  20200531.0  0.453568
# 1035      1    0   9.400  2459000.5      59000  20200531.0  0.533046
# ...     ...  ...     ...        ...        ...         ...       ...
# 958497    1    0  25.846  2458992.5      58992  20200523.0  0.454658
# 958504    1    0  25.409  2459000.5      59000  20200531.0  0.490020
# 958506    1    0  24.980  2458993.5      58993  20200524.0  0.623305
# 958512    1    0  26.980  2458991.5      58991  20200522.0  0.567768
# 958521    1    1  20.400  2459000.5      59000  20200531.0  0.662446
#
#                a         q          i          om           w          ma  \
# ...

# %%
new_df = df.loc[(df['e'] <= upper_limit) & (df['e'] >= lower_limit)]
print('before removing outliers:', len(df))
print('after removing outliers:',len(new_df))
print('outliers:', len(df)-len(new_df))  ##TRIMMING
# Out:
# before removing outliers: 958524
# after removing outliers: 942551
# outliers: 15973

# %%
sns.boxplot(new_df['e'])
# Out:
# <Axes: >

# %%
new_df = df.copy()
new_df.loc[(new_df['e']>=upper_limit), 'e'] = upper_limit
new_df.loc[(new_df['e']<=lower_limit), 'e'] = lower_limit  ##CAPPING

# %%
sns.boxplot(new_df['e'])
# Out:
# <Axes: >

# %%
sns.distplot(new_df['e'])
# Out:
# C:\Users\deagn\AppData\Local\Temp\ipykernel_8964\4198338444.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(new_df['e'])
# <Axes: xlabel='e', ylabel='Density'>

# %% [markdown]
# IQR METHOD

# %%
q1 = df['e'].quantile(0.25)
q3 = df['e'].quantile(0.75)
iqr = q3-q1

# %%
q1, q3, iqr
# Out:
# (0.0921929594309895, 0.2006502939074078, 0.1084573344764183)

# %%
upper_limit = q3 + (1.5 * iqr)
lower_limit = q1 - (1.5 * iqr)
lower_limit, upper_limit
# Out:
# (-0.07049304228363794, 0.36333629562203523)

# %%
df.loc[(df['e'] > upper_limit) | (df['e'] < lower_limit)]
# Out:
#         neo  pha       H      epoch  epoch_mjd   epoch_cal         e  \
# 131       0    0   8.900  2459000.5      59000  20200531.0  0.389559
# 474       0    0  11.500  2459000.5      59000  20200531.0  0.378863
# 698       0    0  11.300  2459000.5      59000  20200531.0  0.410379
# 718       1    0  15.400  2459000.5      59000  20200531.0  0.546558
# 886       1    0  13.800  2459000.5      59000  20200531.0  0.570332
# ...     ...  ...     ...        ...        ...         ...       ...
# 958504    1    0  25.409  2459000.5      59000  20200531.0  0.490020
# 958506    1    0  24.980  2458993.5      58993  20200524.0  0.623305
# 958508    1    0  26.141  2458993.5      58993  20200524.0  0.395881
# 958512    1    0  26.980  2458991.5      58991  20200522.0  0.567768
# 958521    1    1  20.400  2459000.5      59000  20200531.0  0.662446
#
#                a         q          i          om           w          ma  \
# ...

# %%
new_df = df.loc[(df['e'] <= upper_limit) & (df['e'] >= lower_limit)]
print('before removing outliers:', len(df))
print('after removing outliers:',len(new_df)) ##TRIMMING
print('outliers:', len(df)-len(new_df))
# Out:
# before removing outliers: 958524
# after removing outliers: 933724
# outliers: 24800

# %%
sns.boxplot(new_df['e'])
# Out:
# <Axes: >

# %%
sns.distplot(new_df['e'])
# Out:
# C:\Users\deagn\AppData\Local\Temp\ipykernel_8964\4198338444.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(new_df['e'])
# <Axes: xlabel='e', ylabel='Density'>

# %%
new_df = df.copy() ## CAPPING
new_df.loc[(new_df['e']>upper_limit), 'e'] = upper_limit
new_df.loc[(new_df['e']<lower_limit), 'e'] = lower_limit

# %%
sns.boxplot(new_df['e'])
# Out:
# <Axes: >

# %%
sns.distplot(new_df['e'])
# Out:
# C:\Users\deagn\AppData\Local\Temp\ipykernel_8964\4198338444.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(new_df['e'])
# <Axes: xlabel='e', ylabel='Density'>

# %% [markdown]
# percentile method

# %%
upper_limit = df['e'].quantile(0.99)
lower_limit = df['e'].quantile(0.01)
print('upper limit:', upper_limit)
print('lower limit:', lower_limit)
# Out:
# upper limit: 0.5132236565776308
# lower limit: 0.01782410959016686

# %%
df.loc[(df['e'] > upper_limit) | (df['e'] < lower_limit)]
# Out:
#         neo  pha       H      epoch  epoch_mjd   epoch_cal         e  \
# 195       0    0   6.500  2459000.5      59000  20200531.0  0.015724
# 207       0    0   9.200  2459000.5      59000  20200531.0  0.011913
# 310       0    0  10.000  2459000.5      59000  20200531.0  0.004196
# 451       0    0  11.800  2459000.5      59000  20200531.0  0.014405
# 507       0    0   8.400  2459000.5      59000  20200531.0  0.008150
# ...     ...  ...     ...        ...        ...         ...       ...
# 958494    1    0  19.667  2458991.5      58991  20200522.0  0.707372
# 958496    1    0  22.575  2459000.5      59000  20200531.0  0.518885
# 958506    1    0  24.980  2458993.5      58993  20200524.0  0.623305
# 958512    1    0  26.980  2458991.5      58991  20200522.0  0.567768
# 958521    1    1  20.400  2459000.5      59000  20200531.0  0.662446
#
#                a         q          i          om           w          ma  \
# ...

# %%
new_df = df.loc[(df['e'] <= upper_limit) & (df['e'] >= lower_limit)]
print('before removing outliers:', len(df))
print('after removing outliers:',len(new_df))  #TRIMMING
print('outliers:', len(df)-len(new_df))
# Out:
# before removing outliers: 958524
# after removing outliers: 939352
# outliers: 19172

# %%
sns.boxplot(new_df['e'])
# Out:
# <Axes: >

# %%
sns.distplot(new_df['e'])
# Out:
# C:\Users\deagn\AppData\Local\Temp\ipykernel_8964\4198338444.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(new_df['e'])
# <Axes: xlabel='e', ylabel='Density'>

# %%
new_df = df.copy()
new_df.loc[(new_df['e']>upper_limit), 'e'] = upper_limit
new_df.loc[(new_df['e']<lower_limit), 'e'] = lower_limit #CAPPING

# %%
sns.boxplot(new_df['e'])
# Out:
# <Axes: >

# %%
sns.distplot(new_df['e'])
# Out:
# C:\Users\deagn\AppData\Local\Temp\ipykernel_8964\4198338444.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(new_df['e'])
# <Axes: xlabel='e', ylabel='Density'>

# %% [markdown]
# remove outlier(n)

# %%
sns.distplot(df['n'])
# Out:
# C:\Users\deagn\AppData\Local\Temp\ipykernel_8964\58664091.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['n'])
# <Axes: xlabel='n', ylabel='Density'>

# %%
sns.boxplot(df['n'])
# Out:
# <Axes: >

# %% [markdown]
# zscore

# %%
upper_limit = df['n'].mean() + 3*df['n'].std()
lower_limit = df['n'].mean() - 3*df['n'].std()
print('upper limit:', upper_limit)
print('lower limit:', lower_limit)
# Out:
# upper limit: 0.47493575396040666
# lower limit: -0.0015665679664554066

# %%
df.loc[(df['n'] > upper_limit) | (df['n'] < lower_limit)]
# Out:
#         neo  pha       H      epoch  epoch_mjd   epoch_cal         e  \
# 432       1    0  10.400  2459000.5      59000  20200531.0  0.222951
# 1565      1    1  16.900  2459000.5      59000  20200531.0  0.827021
# 1619      1    1  15.300  2459000.5      59000  20200531.0  0.335455
# 1684      1    0  14.300  2459000.5      59000  20200531.0  0.435837
# 1861      1    1  16.250  2459000.5      59000  20200531.0  0.559917
# ...     ...  ...     ...        ...        ...         ...       ...
# 958508    1    0  26.141  2458993.5      58993  20200524.0  0.395881
# 958509    1    0  24.081  2458991.5      58991  20200522.0  0.326254
# 958510    1    0  27.898  2459000.5      59000  20200531.0  0.223160
# 958511    1    0  21.510  2458994.5      58994  20200525.0  0.292102
# 958513    1    0  26.419  2459000.5      59000  20200531.0  0.133246
#
#                a         q          i          om           w          ma  \
# ...

# %%
new_df = df.loc[(df['n'] <= upper_limit) & (df['n'] >= lower_limit)]
print('before removing outliers:', len(df))
print('after removing outliers:',len(new_df))
print('outliers:', len(df)-len(new_df))  ##TRIMMING
# Out:
# before removing outliers: 958524
# after removing outliers: 948016
# outliers: 10508

# %%
sns.boxplot(new_df['n'])
# Out:
# <Axes: >

# %%
new_df = df.copy()
new_df.loc[(new_df['n']>=upper_limit), 'n'] = upper_limit
new_df.loc[(new_df['n']<=lower_limit), 'n'] = lower_limit  ##CAPPING

# %%
sns.boxplot(new_df['n'])
# Out:
# <Axes: >

# %%
sns.distplot(new_df['n'])
# Out:
# C:\Users\deagn\AppData\Local\Temp\ipykernel_8964\1421553223.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(new_df['n'])
# <Axes: xlabel='n', ylabel='Density'>

# %% [markdown]
# IQR method

# %%
q1 = df['n'].quantile(0.25)
q3 = df['n'].quantile(0.75)
iqr = q3-q1

# %%
q1, q3, iqr
# Out:
# (0.18949692936395324, 0.2671142228894967, 0.07761729352554347)

# %%
upper_limit = q3 + (1.5 * iqr)
lower_limit = q1 - (1.5 * iqr)
lower_limit, upper_limit
# Out:
# (0.07307098907563803, 0.3835401631778119)

# %%
df.loc[(df['n'] > upper_limit) | (df['n'] < lower_limit)]
# Out:
#         neo  pha       H      epoch  epoch_mjd   epoch_cal         e  \
# 432       1    0  10.400  2459000.5      59000  20200531.0  0.222951
# 943       0    0  10.700  2459000.5      59000  20200531.0  0.660560
# 1354      0    0  12.900  2459000.5      59000  20200531.0  0.044682
# 1508      0    0  12.600  2459000.5      59000  20200531.0  0.032327
# 1565      1    1  16.900  2459000.5      59000  20200531.0  0.827021
# ...     ...  ...     ...        ...        ...         ...       ...
# 958508    1    0  26.141  2458993.5      58993  20200524.0  0.395881
# 958509    1    0  24.081  2458991.5      58991  20200522.0  0.326254
# 958510    1    0  27.898  2459000.5      59000  20200531.0  0.223160
# 958511    1    0  21.510  2458994.5      58994  20200525.0  0.292102
# 958513    1    0  26.419  2459000.5      59000  20200531.0  0.133246
#
#                a         q          i          om           w          ma  \
# ...

# %%
new_df = df.loc[(df['n'] <= upper_limit) & (df['n'] >= lower_limit)]
print('before removing outliers:', len(df))
print('after removing outliers:',len(new_df)) ##TRIMMING
print('outliers:', len(df)-len(new_df))
# Out:
# before removing outliers: 958524
# after removing outliers: 934418
# outliers: 24106

# %%
sns.boxplot(new_df['n'])
# Out:
# <Axes: >

# %%
sns.distplot(new_df['n'])
# Out:
# C:\Users\deagn\AppData\Local\Temp\ipykernel_8964\1421553223.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(new_df['n'])
# <Axes: xlabel='n', ylabel='Density'>

# %%
new_df = df.copy() ## CAPPING
new_df.loc[(new_df['n']>upper_limit), 'n'] = upper_limit
new_df.loc[(new_df['n']<lower_limit), 'n'] = lower_limit

# %%
sns.boxplot(new_df['moid'])
# Out:
# <Axes: >

# %%
sns.distplot(new_df['n'])
# Out:
# C:\Users\deagn\AppData\Local\Temp\ipykernel_8964\1421553223.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(new_df['n'])
# <Axes: xlabel='n', ylabel='Density'>

# %% [markdown]
# Percentile method

# %%
upper_limit = df['n'].quantile(0.99)
lower_limit = df['n'].quantile(0.01)
print('upper limit:', upper_limit)
print('lower limit:', lower_limit)
# Out:
# upper limit: 0.5057755989587447
# lower limit: 0.08373414763286269

# %%
df.loc[(df['n'] > upper_limit) | (df['n'] < lower_limit)]
# Out:
#         neo  pha       H      epoch  epoch_mjd   epoch_cal         e  \
# 432       1    0  10.400  2459000.5      59000  20200531.0  0.222951
# 587       0    0   8.300  2459000.5      59000  20200531.0  0.147122
# 616       0    0   8.200  2459000.5      59000  20200531.0  0.138967
# 623       0    0   7.200  2459000.5      59000  20200531.0  0.022797
# 883       0    0   8.700  2459000.5      59000  20200531.0  0.123272
# ...     ...  ...     ...        ...        ...         ...       ...
# 958505    1    0  24.371  2458991.5      58991  20200522.0  0.358703
# 958507    1    0  29.913  2459000.5      59000  20200531.0  0.136255
# 958510    1    0  27.898  2459000.5      59000  20200531.0  0.223160
# 958511    1    0  21.510  2458994.5      58994  20200525.0  0.292102
# 958513    1    0  26.419  2459000.5      59000  20200531.0  0.133246
#
#                a         q          i          om           w          ma  \
# ...

# %%
new_df = df.loc[(df['n'] <= upper_limit) & (df['n'] >= lower_limit)]
print('before removing outliers:', len(df))
print('after removing outliers:',len(new_df))  #TRIMMING
print('outliers:', len(df)-len(new_df))
# Out:
# before removing outliers: 958524
# after removing outliers: 939352
# outliers: 19172

# %%
sns.boxplot(new_df['n'])
# Out:
# <Axes: >

# %%
sns.distplot(new_df['n'])
# Out:
# C:\Users\deagn\AppData\Local\Temp\ipykernel_8964\1421553223.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(new_df['n'])
# <Axes: xlabel='n', ylabel='Density'>

# %%
new_df = df.copy()
new_df.loc[(new_df['n']>upper_limit), 'n'] = upper_limit
new_df.loc[(new_df['n']<lower_limit), 'n'] = lower_limit #CAPPING

# %%
sns.boxplot(new_df['n'])
# Out:
# <Axes: >

# %%
sns.distplot(new_df['n'])
# Out:
# C:\Users\deagn\AppData\Local\Temp\ipykernel_8964\1421553223.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(new_df['n'])
# <Axes: xlabel='n', ylabel='Density'>

# %% [markdown]
# remove outlier(ad)

# %%
df.describe()
# Out:
#                  neo            pha              H         epoch  \
# count  958524.000000  958524.000000  958524.000000  9.585240e+05
# mean        0.023886       0.002155      16.906411  2.458869e+06
# std         0.152693       0.046376       1.784546  7.016716e+02
# min         0.000000       0.000000      -1.100000  2.425052e+06
# 25%         0.000000       0.000000      16.100000  2.459000e+06
# 50%         0.000000       0.000000      16.900000  2.459000e+06
# 75%         0.000000       0.000000      17.700000  2.459000e+06
# max         1.000000       1.000000      33.200000  2.459000e+06
#
#            epoch_mjd     epoch_cal              e              a  \
# count  958524.000000  9.585240e+05  958524.000000  958524.000000
# mean    58868.781950  2.019693e+07       0.156116       2.902143
# std       701.671573  1.930354e+04       0.092643      39.719503
# min     25051.000000  1.927062e+07       0.000000  -14702.447872
# ...

# %%
sns.distplot(df['ad'])
# Out:
# C:\Users\deagn\AppData\Local\Temp\ipykernel_8964\344350860.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['ad'])
# <Axes: xlabel='ad', ylabel='Density'>

# %%
sns.boxplot(df['ad'])
# Out:
# <Axes: >

# %% [markdown]
# zscore

# %%
upper_limit = df['ad'].mean() + 3*df['ad'].std()
lower_limit = df['ad'].mean() - 3*df['ad'].std()
print('upper limit:', upper_limit)
print('lower limit:', lower_limit)
# Out:
# upper limit: 218.7635750671348
# lower limit: -211.8519345274051

# %%
df.loc[(df['ad'] > upper_limit) | (df['ad'] < lower_limit)]
# Out:
#         neo  pha       H      epoch  epoch_mjd   epoch_cal         e  \
# 54519     0    0   8.000  2459000.5      59000  20200531.0  0.773084
# 82157     0    0   6.200  2459000.5      59000  20200531.0  0.843755
# 87268     0    0   9.200  2459000.5      59000  20200531.0  0.963287
# 90376     0    0   1.300  2459000.5      59000  20200531.0  0.842587
# 148208    0    0   6.300  2459000.5      59000  20200531.0  0.796010
# ...     ...  ...     ...        ...        ...         ...       ...
# 954927    0    0  12.735  2458784.5      58784  20191028.0  0.998459
# 955732    0    0  10.278  2458868.5      58868  20200120.0  0.999591
# 956944    0    0  14.162  2458887.5      58887  20200208.0  0.993775
# 957913    0    0  11.834  2458914.5      58914  20200306.0  0.993370
# 958257    0    0  17.641  2458975.5      58975  20200506.0  0.994756
#
#                   a          q           i          om           w  \
# 54519    126.676758  28.744955    5.684378  293.094810  304.425665
# ...

# %%
new_df = df.loc[(df['ad'] <= upper_limit) & (df['ad'] >= lower_limit)]
print('before removing outliers:', len(df))
print('after removing outliers:',len(new_df))
print('outliers:', len(df)-len(new_df))  ##TRIMMING
# Out:
# before removing outliers: 958524
# after removing outliers: 958428
# outliers: 96

# %%
sns.boxplot(new_df['ad'])
# Out:
# <Axes: >

# %%
new_df = df.copy()
new_df.loc[(new_df['ad']>=upper_limit), 'ad'] = upper_limit
new_df.loc[(new_df['ad']<=lower_limit), 'ad'] = lower_limit  ##CAPPING

# %%
sns.boxplot(new_df['ad'])
# Out:
# <Axes: >

# %%
sns.distplot(new_df['ad'])
# Out:
# C:\Users\deagn\AppData\Local\Temp\ipykernel_8964\4030894395.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(new_df['ad'])
# <Axes: xlabel='ad', ylabel='Density'>

# %% [markdown]
# IQR Method

# %%
q1 = df['ad'].quantile(0.25)
q3 = df['ad'].quantile(0.75)
iqr = q3-q1

# %%
q1, q3, iqr
# Out:
# (2.781603934723136, 3.3647989444427746, 0.5831950097196388)

# %%
upper_limit = q3 + (1.5 * iqr)
lower_limit = q1 - (1.5 * iqr)
lower_limit, upper_limit
# Out:
# (1.9068114201436777, 4.2395914590222326)

# %%
df.loc[(df['ad'] > upper_limit) | (df['ad'] < lower_limit)]
# Out:
#         neo  pha       H      epoch  epoch_mjd   epoch_cal         e  \
# 152       0    0   7.600  2459000.5      59000  20200531.0  0.140283
# 189       0    0   7.700  2459000.5      59000  20200531.0  0.166708
# 224       0    0   8.800  2459000.5      59000  20200531.0  0.263602
# 278       0    0   8.500  2459000.5      59000  20200531.0  0.042520
# 360       0    0   8.400  2459000.5      59000  20200531.0  0.212021
# ...     ...  ...     ...        ...        ...         ...       ...
# 958507    1    0  29.913  2459000.5      59000  20200531.0  0.136255
# 958510    1    0  27.898  2459000.5      59000  20200531.0  0.223160
# 958511    1    0  21.510  2458994.5      58994  20200525.0  0.292102
# 958513    1    0  26.419  2459000.5      59000  20200531.0  0.133246
# 958521    1    1  20.400  2459000.5      59000  20200531.0  0.662446
#
#                a         q          i          om           w          ma  \
# ...

# %%
new_df = df.loc[(df['ad'] <= upper_limit) & (df['ad'] >= lower_limit)]
print('before removing outliers:', len(df))
print('after removing outliers:',len(new_df)) ##TRIMMING
print('outliers:', len(df)-len(new_df))
# Out:
# before removing outliers: 958524
# after removing outliers: 928590
# outliers: 29934

# %%
sns.boxplot(new_df['ad'])
# Out:
# <Axes: >

# %%
sns.distplot(new_df['ad'])
# Out:
# C:\Users\deagn\AppData\Local\Temp\ipykernel_8964\4030894395.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(new_df['ad'])
# <Axes: xlabel='ad', ylabel='Density'>

# %%
new_df = df.copy() ## CAPPING
new_df.loc[(new_df['ad']>upper_limit), 'ad'] = upper_limit
new_df.loc[(new_df['ad']<lower_limit), 'ad'] = lower_limit

# %%
sns.boxplot(new_df['ad'])
# Out:
# <Axes: >

# %%
sns.distplot(new_df['ad'])
# Out:
# C:\Users\deagn\AppData\Local\Temp\ipykernel_8964\4030894395.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(new_df['ad'])
# <Axes: xlabel='ad', ylabel='Density'>

# %% [markdown]
# Percentile method

# %%
upper_limit = df['ad'].quantile(0.99)
lower_limit = df['ad'].quantile(0.01)
print('upper limit:', upper_limit)
print('lower limit:', lower_limit)
# Out:
# upper limit: 5.4827854022062406
# lower limit: 1.9425651491534344

# %%
df.loc[(df['ad'] > upper_limit) | (df['ad'] < lower_limit)]
# Out:
#         neo  pha       H      epoch  epoch_mjd   epoch_cal         e  \
# 432       1    0  10.400  2459000.5      59000  20200531.0  0.222951
# 587       0    0   8.300  2459000.5      59000  20200531.0  0.147122
# 616       0    0   8.200  2459000.5      59000  20200531.0  0.138967
# 658       0    0   8.700  2459000.5      59000  20200531.0  0.117448
# 883       0    0   8.700  2459000.5      59000  20200531.0  0.123272
# ...     ...  ...     ...        ...        ...         ...       ...
# 958505    1    0  24.371  2458991.5      58991  20200522.0  0.358703
# 958507    1    0  29.913  2459000.5      59000  20200531.0  0.136255
# 958510    1    0  27.898  2459000.5      59000  20200531.0  0.223160
# 958511    1    0  21.510  2458994.5      58994  20200525.0  0.292102
# 958513    1    0  26.419  2459000.5      59000  20200531.0  0.133246
#
#                a         q          i          om           w          ma  \
# ...

# %%
new_df = df.loc[(df['ad'] <= upper_limit) & (df['ad'] >= lower_limit)]
print('before removing outliers:', len(df))
print('after removing outliers:',len(new_df))  #TRIMMING
print('outliers:', len(df)-len(new_df))
# Out:
# before removing outliers: 958524
# after removing outliers: 939352
# outliers: 19172

# %%
sns.boxplot(new_df['ad'])
# Out:
# <Axes: >

# %%
sns.distplot(new_df['ad'])
# Out:
# C:\Users\deagn\AppData\Local\Temp\ipykernel_8964\4030894395.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(new_df['ad'])
# <Axes: xlabel='ad', ylabel='Density'>

# %%
new_df = df.copy()
new_df.loc[(new_df['ad']>upper_limit), 'ad'] = upper_limit
new_df.loc[(new_df['ad']<lower_limit), 'ad'] = lower_limit #CAPPING

# %%
sns.boxplot(new_df['ad'])
# Out:
# <Axes: >

# %%
sns.distplot(new_df['ad'])
# Out:
# C:\Users\deagn\AppData\Local\Temp\ipykernel_8964\4030894395.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(new_df['ad'])
# <Axes: xlabel='ad', ylabel='Density'>

# %% [markdown]
# remove outlier(ma)

# %%
df.describe()
# Out:
#                  neo            pha              H         epoch  \
# count  958524.000000  958524.000000  958524.000000  9.585240e+05
# mean        0.023886       0.002155      16.906411  2.458869e+06
# std         0.152693       0.046376       1.784546  7.016716e+02
# min         0.000000       0.000000      -1.100000  2.425052e+06
# 25%         0.000000       0.000000      16.100000  2.459000e+06
# 50%         0.000000       0.000000      16.900000  2.459000e+06
# 75%         0.000000       0.000000      17.700000  2.459000e+06
# max         1.000000       1.000000      33.200000  2.459000e+06
#
#            epoch_mjd     epoch_cal              e              a  \
# count  958524.000000  9.585240e+05  958524.000000  958524.000000
# mean    58868.781950  2.019693e+07       0.156116       2.902143
# std       701.671573  1.930354e+04       0.092643      39.719503
# min     25051.000000  1.927062e+07       0.000000  -14702.447872
# ...

# %%
sns.distplot(df['ma'])
# Out:
# C:\Users\deagn\AppData\Local\Temp\ipykernel_8964\1496730972.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['ma'])
# <Axes: xlabel='ma', ylabel='Density'>

# %%
sns.boxplot(df['ma'])
# Out:
# <Axes: >

# %% [markdown]
# zscore

# %%
upper_limit = df['ma'].mean() + 3*df['ma'].std()
lower_limit = df['ma'].mean() - 3*df['ma'].std()
print('upper limit:', upper_limit)
print('lower limit:', lower_limit)
# Out:
# upper limit: 494.80294786362623
# lower limit: -140.09778338539576

# %%
df.loc[(df['ma'] > upper_limit) | (df['ma'] < lower_limit)]
# Out:
# Empty DataFrame
# Columns: [neo, pha, H, epoch, epoch_mjd, epoch_cal, e, a, q, i, om, w, ma, ad, n, tp, tp_cal, per, per_y, moid, moid_ld, OrbitType, rms]
# Index: []

# %%
new_df = df.loc[(df['ma'] <= upper_limit) & (df['ma'] >= lower_limit)]
print('before removing outliers:', len(df))
print('after removing outliers:',len(new_df))
print('outliers:', len(df)-len(new_df))  ##TRIMMING
# Out:
# before removing outliers: 958524
# after removing outliers: 958524
# outliers: 0

# %%
sns.boxplot(new_df['ma'])
# Out:
# <Axes: >

# %%
new_df = df.copy()
new_df.loc[(new_df['ma']>=upper_limit), 'ma'] = upper_limit
new_df.loc[(new_df['ma']<=lower_limit), 'ma'] = lower_limit  ##CAPPING

# %%
sns.boxplot(new_df['ma'])
# Out:
# <Axes: >

# %%
sns.distplot(new_df['ma'])
# Out:
# C:\Users\deagn\AppData\Local\Temp\ipykernel_8964\2508951504.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(new_df['ma'])
# <Axes: xlabel='ma', ylabel='Density'>

# %% [markdown]
# NO OUTLIER IN ma

# %%
df.describe()
# Out:
#                  neo            pha              H         epoch  \
# count  958524.000000  958524.000000  958524.000000  9.585240e+05
# mean        0.023886       0.002155      16.906411  2.458869e+06
# std         0.152693       0.046376       1.784546  7.016716e+02
# min         0.000000       0.000000      -1.100000  2.425052e+06
# 25%         0.000000       0.000000      16.100000  2.459000e+06
# 50%         0.000000       0.000000      16.900000  2.459000e+06
# 75%         0.000000       0.000000      17.700000  2.459000e+06
# max         1.000000       1.000000      33.200000  2.459000e+06
#
#            epoch_mjd     epoch_cal              e              a  \
# count  958524.000000  9.585240e+05  958524.000000  958524.000000
# mean    58868.781950  2.019693e+07       0.156116       2.902143
# std       701.671573  1.930354e+04       0.092643      39.719503
# min     25051.000000  1.927062e+07       0.000000  -14702.447872
# ...

# %% [markdown]
# removal outlier(i)

# %%
sns.distplot(df['i'])
# Out:
# C:\Users\deagn\AppData\Local\Temp\ipykernel_8964\3846146552.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['i'])
# <Axes: xlabel='i', ylabel='Density'>

# %%
sns.boxplot(df['i'])
# Out:
# <Axes: >

# %% [markdown]
# Zscore

# %%
upper_limit = df['i'].mean() + 3*df['i'].std()
lower_limit = df['i'].mean() - 3*df['i'].std()
print('upper limit:', upper_limit)
print('lower limit:', lower_limit)
# Out:
# upper limit: 28.96786826404034
# lower limit: -10.858066369156356

# %%
df.loc[(df['i'] > upper_limit) | (df['i'] < lower_limit)]
# Out:
#         neo  pha       H      epoch  epoch_mjd   epoch_cal         e  \
# 1         0    0   4.200  2459000.5      59000  20200531.0  0.229972
# 530       0    0  12.000  2459000.5      59000  20200531.0  0.197304
# 581       0    0   9.000  2459000.5      59000  20200531.0  0.222399
# 593       0    0  12.100  2459000.5      59000  20200531.0  0.352838
# 943       0    0  10.700  2459000.5      59000  20200531.0  0.660560
# ...     ...  ...     ...        ...        ...         ...       ...
# 958471    1    0  19.119  2458989.5      58989  20200520.0  0.571390
# 958494    1    0  19.667  2458991.5      58991  20200522.0  0.707372
# 958498    1    0  22.796  2458989.5      58989  20200520.0  0.294912
# 958500    0    0  18.500  2458980.5      58980  20200511.0  0.387112
# 958511    1    0  21.510  2458994.5      58994  20200525.0  0.292102
#
#                a         q          i          om           w          ma  \
# ...

# %%
new_df = df.loc[(df['i'] <= upper_limit) & (df['i'] >= lower_limit)]
print('before removing outliers:', len(df))
print('after removing outliers:',len(new_df))
print('outliers:', len(df)-len(new_df))  ##TRIMMING
# Out:
# before removing outliers: 958524
# after removing outliers: 948605
# outliers: 9919

# %%
sns.boxplot(new_df['i'])
# Out:
# <Axes: >

# %%
new_df = df.copy()
new_df.loc[(new_df['i']>=upper_limit), 'i'] = upper_limit
new_df.loc[(new_df['i']<=lower_limit), 'i'] = lower_limit  ##CAPPING

# %%
sns.boxplot(new_df['i'])
# Out:
# <Axes: >

# %%
sns.distplot(new_df['i'])
# Out:
# C:\Users\deagn\AppData\Local\Temp\ipykernel_8964\3376830630.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(new_df['i'])
# <Axes: xlabel='i', ylabel='Density'>

# %% [markdown]
# IQR method

# %%
q1 = df['i'].quantile(0.25)
q3 = df['i'].quantile(0.75)
iqr = q3-q1

# %%
q1, q3, iqr
# Out:
# (4.165419371225029, 12.407550308262199, 8.24213093703717)

# %%
upper_limit = q3 + (1.5 * iqr)
lower_limit = q1 - (1.5 * iqr)
lower_limit, upper_limit
# Out:
# (-8.197777034330725, 24.770746713817953)

# %%
df.loc[(df['i'] > upper_limit) | (df['i'] < lower_limit)]
# Out:
#         neo  pha       H      epoch  epoch_mjd   epoch_cal         e  \
# 1         0    0   4.200  2459000.5      59000  20200531.0  0.229972
# 30        0    0   6.800  2459000.5      59000  20200531.0  0.219942
# 131       0    0   8.900  2459000.5      59000  20200531.0  0.389559
# 147       0    0   7.600  2459000.5      59000  20200531.0  0.187225
# 182       0    0   9.600  2459000.5      59000  20200531.0  0.349769
# ...     ...  ...     ...        ...        ...         ...       ...
# 958494    1    0  19.667  2458991.5      58991  20200522.0  0.707372
# 958498    1    0  22.796  2458989.5      58989  20200520.0  0.294912
# 958500    0    0  18.500  2458980.5      58980  20200511.0  0.387112
# 958509    1    0  24.081  2458991.5      58991  20200522.0  0.326254
# 958511    1    0  21.510  2458994.5      58994  20200525.0  0.292102
#
#                a         q          i          om           w          ma  \
# ...

# %%
new_df = df.loc[(df['i'] <= upper_limit) & (df['i'] >= lower_limit)]
print('before removing outliers:', len(df))
print('after removing outliers:',len(new_df)) ##TRIMMING
print('outliers:', len(df)-len(new_df))
# Out:
# before removing outliers: 958524
# after removing outliers: 928239
# outliers: 30285

# %%
sns.boxplot(new_df['i'])
# Out:
# <Axes: >

# %%
sns.distplot(new_df['i'])
# Out:
# C:\Users\deagn\AppData\Local\Temp\ipykernel_8964\3376830630.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(new_df['i'])
# <Axes: xlabel='i', ylabel='Density'>

# %%
new_df = df.copy() ## CAPPING
new_df.loc[(new_df['i']>upper_limit), 'i'] = upper_limit
new_df.loc[(new_df['i']<lower_limit), 'i'] = lower_limit

# %%
sns.boxplot(new_df['i'])
# Out:
# <Axes: >

# %%
sns.distplot(new_df['i'])
# Out:
# C:\Users\deagn\AppData\Local\Temp\ipykernel_8964\3376830630.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(new_df['i'])
# <Axes: xlabel='i', ylabel='Density'>

# %% [markdown]
# Percentile method

# %%
upper_limit = df['i'].quantile(0.99)
lower_limit = df['i'].quantile(0.01)
print('upper limit:', upper_limit)
print('lower limit:', lower_limit)
# Out:
# upper limit: 29.079618696697498
# lower limit: 0.746290316835373

# %%
df.loc[(df['i'] > upper_limit) | (df['i'] < lower_limit)]
# Out:
#         neo  pha       H      epoch  epoch_mjd   epoch_cal         e  \
# 1         0    0   4.200  2459000.5      59000  20200531.0  0.229972
# 19        0    0   6.500  2459000.5      59000  20200531.0  0.142494
# 299       0    0   9.800  2459000.5      59000  20200531.0  0.057444
# 467       0    0   9.700  2459000.5      59000  20200531.0  0.197408
# 530       0    0  12.000  2459000.5      59000  20200531.0  0.197304
# ...     ...  ...     ...        ...        ...         ...       ...
# 958494    1    0  19.667  2458991.5      58991  20200522.0  0.707372
# 958498    1    0  22.796  2458989.5      58989  20200520.0  0.294912
# 958500    0    0  18.500  2458980.5      58980  20200511.0  0.387112
# 958511    1    0  21.510  2458994.5      58994  20200525.0  0.292102
# 958522    0    0  18.071  2441956.5      41956  19731001.0  0.202053
#
#                a         q          i          om           w          ma  \
# ...

# %%
new_df = df.loc[(df['i'] <= upper_limit) & (df['i'] >= lower_limit)]
print('before removing outliers:', len(df))
print('after removing outliers:',len(new_df))  #TRIMMING
print('outliers:', len(df)-len(new_df))
# Out:
# before removing outliers: 958524
# after removing outliers: 939352
# outliers: 19172

# %%
sns.boxplot(new_df['i'])
# Out:
# <Axes: >

# %%
sns.distplot(new_df['i'])
# Out:
# C:\Users\deagn\AppData\Local\Temp\ipykernel_8964\3376830630.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(new_df['i'])
# <Axes: xlabel='i', ylabel='Density'>

# %%
new_df = df.copy()
new_df.loc[(new_df['i']>upper_limit), 'i'] = upper_limit
new_df.loc[(new_df['i']<lower_limit), 'i'] = lower_limit #CAPPING

# %%
sns.boxplot(new_df['i'])
# Out:
# <Axes: >

# %%
sns.distplot(new_df['i'])
# Out:
# C:\Users\deagn\AppData\Local\Temp\ipykernel_8964\3376830630.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(new_df['i'])
# <Axes: xlabel='i', ylabel='Density'>

# %%
df.describe()
# Out:
#                  neo            pha              H         epoch  \
# count  958524.000000  958524.000000  958524.000000  9.585240e+05
# mean        0.023886       0.002155      16.906411  2.458869e+06
# std         0.152693       0.046376       1.784546  7.016716e+02
# min         0.000000       0.000000      -1.100000  2.425052e+06
# 25%         0.000000       0.000000      16.100000  2.459000e+06
# 50%         0.000000       0.000000      16.900000  2.459000e+06
# 75%         0.000000       0.000000      17.700000  2.459000e+06
# max         1.000000       1.000000      33.200000  2.459000e+06
#
#            epoch_mjd     epoch_cal              e              a  \
# count  958524.000000  9.585240e+05  958524.000000  958524.000000
# mean    58868.781950  2.019693e+07       0.156116       2.902143
# std       701.671573  1.930354e+04       0.092643      39.719503
# min     25051.000000  1.927062e+07       0.000000  -14702.447872
# ...

# %% [markdown]
# outlier remove(q)

# %%
sns.distplot(df['q'])
# Out:
# C:\Users\deagn\AppData\Local\Temp\ipykernel_8964\3209057737.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['q'])
# <Axes: xlabel='q', ylabel='Density'>

# %%
sns.boxplot(df['q'])
# Out:
# <Axes: >

# %% [markdown]
# Zscore

# %%
upper_limit = df['q'].mean() + 3*df['q'].std()
lower_limit = df['q'].mean() - 3*df['q'].std()
print('upper limit:', upper_limit)
print('lower limit:', lower_limit)
# Out:
# upper limit: 8.812624981739237
# lower limit: -4.022850012324314

# %%
df.loc[(df['q'] > upper_limit) | (df['q'] < lower_limit)]
# Out:
#         neo  pha        H      epoch  epoch_mjd   epoch_cal         e  \
# 7065      0    0   9.6000  2459000.5      59000  20200531.0  0.517555
# 10198     0    0   6.6000  2459000.5      59000  20200531.0  0.169256
# 10369     0    0   8.6000  2459000.5      59000  20200531.0  0.245579
# 15759     0    0   7.1000  2459000.5      59000  20200531.0  0.070956
# 15787     0    0   7.9000  2459000.5      59000  20200531.0  0.316890
# ...     ...  ...      ...        ...        ...         ...       ...
# 950563    0    0   9.1017  2458842.5      58842  20191225.0  1.001173
# 952472    0    0   6.8441  2458749.5      58749  20190923.0  0.093291
# 954955    0    0  11.9000  2459000.5      59000  20200531.0  0.519137
# 957579    0    0   6.6146  2458893.5      58893  20200214.0  0.614485
# 957706    0    0  10.0720  2459000.5      59000  20200531.0  0.482458
#
#                   a          q          i          om           w          ma  \
# ...

# %%
new_df = df.loc[(df['q'] <= upper_limit) & (df['q'] >= lower_limit)]
print('before removing outliers:', len(df))
print('after removing outliers:',len(new_df))
print('outliers:', len(df)-len(new_df))  ##TRIMMING
# Out:
# before removing outliers: 958524
# after removing outliers: 954934
# outliers: 3590

# %%
sns.boxplot(new_df['q'])
# Out:
# <Axes: >

# %%
new_df = df.copy()
new_df.loc[(new_df['q']>=upper_limit), 'q'] = upper_limit
new_df.loc[(new_df['q']<=lower_limit), 'q'] = lower_limit  ##CAPPING

# %%
sns.boxplot(new_df['q'])
# Out:
# <Axes: >

# %%
sns.distplot(new_df['q'])
# Out:
# C:\Users\deagn\AppData\Local\Temp\ipykernel_8964\3629188693.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(new_df['q'])
# <Axes: xlabel='q', ylabel='Density'>

# %% [markdown]
# IQR method

# %%
q1 = df['q'].quantile(0.25)
q3 = df['q'].quantile(0.75)
iqr = q3-q1

# %%
q1, q3, iqr
# Out:
# (1.9714005193444777, 2.578314846230455, 0.6069143268859771)

# %%
upper_limit = q3 + (1.5 * iqr)
lower_limit = q1 - (1.5 * iqr)
lower_limit, upper_limit
# Out:
# (1.061029029015512, 3.4886863365594207)

# %%
df.loc[(df['q'] > upper_limit) | (df['q'] < lower_limit)]
# Out:
#         neo  pha       H      epoch  epoch_mjd   epoch_cal         e  \
# 278       0    0   8.500  2459000.5      59000  20200531.0  0.042520
# 333       0    0   7.700  2459000.5      59000  20200531.0  0.023761
# 587       0    0   8.300  2459000.5      59000  20200531.0  0.147122
# 616       0    0   8.200  2459000.5      59000  20200531.0  0.138967
# 623       0    0   7.200  2459000.5      59000  20200531.0  0.022797
# ...     ...  ...     ...        ...        ...         ...       ...
# 958510    1    0  27.898  2459000.5      59000  20200531.0  0.223160
# 958511    1    0  21.510  2458994.5      58994  20200525.0  0.292102
# 958512    1    0  26.980  2458991.5      58991  20200522.0  0.567768
# 958513    1    0  26.419  2459000.5      59000  20200531.0  0.133246
# 958521    1    1  20.400  2459000.5      59000  20200531.0  0.662446
#
#                a         q          i          om           w          ma  \
# ...

# %%
new_df = df.loc[(df['q'] <= upper_limit) & (df['q'] >= lower_limit)]
print('before removing outliers:', len(df))
print('after removing outliers:',len(new_df)) ##TRIMMING
print('outliers:', len(df)-len(new_df))
# Out:
# before removing outliers: 958524
# after removing outliers: 929094
# outliers: 29430

# %%
sns.boxplot(new_df['q'])
# Out:
# <Axes: >

# %%
sns.distplot(new_df['q'])
# Out:
# C:\Users\deagn\AppData\Local\Temp\ipykernel_8964\3629188693.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(new_df['q'])
# <Axes: xlabel='q', ylabel='Density'>

# %%
new_df = df.copy() ## CAPPING
new_df.loc[(new_df['q']>upper_limit), 'q'] = upper_limit
new_df.loc[(new_df['q']<lower_limit), 'q'] = lower_limit

# %%
sns.boxplot(new_df['q'])
# Out:
# <Axes: >

# %%
sns.distplot(new_df['q'])
# Out:
# C:\Users\deagn\AppData\Local\Temp\ipykernel_8964\3629188693.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(new_df['q'])
# <Axes: xlabel='q', ylabel='Density'>

# %% [markdown]
# Percentile Method

# %%
upper_limit = df['q'].quantile(0.99)
lower_limit = df['q'].quantile(0.01)
print('upper limit:', upper_limit)
print('lower limit:', lower_limit)
# Out:
# upper limit: 4.729809280661737
# lower limit: 0.9168874488449616

# %%
df.loc[(df['q'] > upper_limit) | (df['q'] < lower_limit)]
# Out:
#         neo  pha       H      epoch  epoch_mjd   epoch_cal         e  \
# 623       0    0   7.200  2459000.5      59000  20200531.0  0.022797
# 910       0    0   7.900  2459000.5      59000  20200531.0  0.066503
# 1142      0    0   8.300  2459000.5      59000  20200531.0  0.090534
# 1207      0    0   9.000  2459000.5      59000  20200531.0  0.091767
# 1436      0    0   8.200  2459000.5      59000  20200531.0  0.043815
# ...     ...  ...     ...        ...        ...         ...       ...
# 958494    1    0  19.667  2458991.5      58991  20200522.0  0.707372
# 958501    1    0  27.002  2458993.5      58993  20200524.0  0.365054
# 958505    1    0  24.371  2458991.5      58991  20200522.0  0.358703
# 958507    1    0  29.913  2459000.5      59000  20200531.0  0.136255
# 958511    1    0  21.510  2458994.5      58994  20200525.0  0.292102
#
#                a         q          i          om           w          ma  \
# ...

# %%
new_df = df.loc[(df['q'] <= upper_limit) & (df['q'] >= lower_limit)]
print('before removing outliers:', len(df))
print('after removing outliers:',len(new_df))  #TRIMMING
print('outliers:', len(df)-len(new_df))
# Out:
# before removing outliers: 958524
# after removing outliers: 939352
# outliers: 19172

# %%
sns.boxplot(new_df['q'])
# Out:
# <Axes: >

# %%
sns.distplot(new_df['q'])
# Out:
# C:\Users\deagn\AppData\Local\Temp\ipykernel_8964\3629188693.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(new_df['q'])
# <Axes: xlabel='q', ylabel='Density'>

# %%
new_df = df.copy()
new_df.loc[(new_df['q']>upper_limit), 'q'] = upper_limit
new_df.loc[(new_df['q']<lower_limit), 'q'] = lower_limit #CAPPING

# %%
sns.boxplot(new_df['q'])
# Out:
# <Axes: >

# %%
sns.distplot(new_df['q'])
# Out:
# C:\Users\deagn\AppData\Local\Temp\ipykernel_8964\3629188693.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(new_df['q'])
# <Axes: xlabel='q', ylabel='Density'>

# %% [markdown]
# remove outlier(a)

# %%
sns.distplot(df['a'])
# Out:
# C:\Users\deagn\AppData\Local\Temp\ipykernel_8964\2271900559.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['a'])
# <Axes: xlabel='a', ylabel='Density'>

# %%
sns.boxplot(df['a'])
# Out:
# <Axes: >

# %% [markdown]
# zscore

# %%
upper_limit = df['a'].mean() + 3*df['a'].std()
lower_limit = df['a'].mean() - 3*df['a'].std()
print('upper limit:', upper_limit)
print('lower limit:', lower_limit)
# Out:
# upper limit: 122.0606528825566
# lower limit: -116.25636621628566

# %%
df.loc[(df['a'] > upper_limit) | (df['a'] < lower_limit)]
# Out:
#         neo  pha       H      epoch  epoch_mjd   epoch_cal         e  \
# 54519     0    0   8.000  2459000.5      59000  20200531.0  0.773084
# 82157     0    0   6.200  2459000.5      59000  20200531.0  0.843755
# 87268     0    0   9.200  2459000.5      59000  20200531.0  0.963287
# 90376     0    0   1.300  2459000.5      59000  20200531.0  0.842587
# 148208    0    0   6.300  2459000.5      59000  20200531.0  0.796010
# ...     ...  ...     ...        ...        ...         ...       ...
# 954927    0    0  12.735  2458784.5      58784  20191028.0  0.998459
# 955732    0    0  10.278  2458868.5      58868  20200120.0  0.999591
# 956944    0    0  14.162  2458887.5      58887  20200208.0  0.993775
# 957913    0    0  11.834  2458914.5      58914  20200306.0  0.993370
# 958257    0    0  17.641  2458975.5      58975  20200506.0  0.994756
#
#                   a          q           i          om           w  \
# 54519    126.676758  28.744955    5.684378  293.094810  304.425665
# ...

# %%
new_df = df.loc[(df['a'] <= upper_limit) & (df['a'] >= lower_limit)]
print('before removing outliers:', len(df))
print('after removing outliers:',len(new_df))
print('outliers:', len(df)-len(new_df))  ##TRIMMING
# Out:
# before removing outliers: 958524
# after removing outliers: 958423
# outliers: 101

# %%
sns.boxplot(new_df['a'])
# Out:
# <Axes: >

# %%
new_df = df.copy()
new_df.loc[(new_df['a']>=upper_limit), 'a'] = upper_limit
new_df.loc[(new_df['a']<=lower_limit), 'a'] = lower_limit  ##CAPPING

# %%
sns.boxplot(new_df['a'])
# Out:
# <Axes: >

# %%
sns.distplot(new_df['a'])
# Out:
# C:\Users\deagn\AppData\Local\Temp\ipykernel_8964\2551995574.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(new_df['a'])
# <Axes: xlabel='a', ylabel='Density'>

# %% [markdown]
# IQR method

# %%
q1 = df['a'].quantile(0.25)
q3 = df['a'].quantile(0.75)
iqr = q3-q1

# %%
q1, q3, iqr
# Out:
# (2.38783527871163, 3.001932494974786, 0.6140972162631559)

# %%
upper_limit = q3 + (1.5 * iqr)
lower_limit = q1 - (1.5 * iqr)
lower_limit, upper_limit
# Out:
# (1.4666894543168962, 3.92307831936952)

# %%
df.loc[(df['a'] > upper_limit) | (df['a'] < lower_limit)]
# Out:
#         neo  pha       H      epoch  epoch_mjd   epoch_cal         e  \
# 152       0    0   7.600  2459000.5      59000  20200531.0  0.140283
# 189       0    0   7.700  2459000.5      59000  20200531.0  0.166708
# 278       0    0   8.500  2459000.5      59000  20200531.0  0.042520
# 360       0    0   8.400  2459000.5      59000  20200531.0  0.212021
# 432       1    0  10.400  2459000.5      59000  20200531.0  0.222951
# ...     ...  ...     ...        ...        ...         ...       ...
# 958505    1    0  24.371  2458991.5      58991  20200522.0  0.358703
# 958507    1    0  29.913  2459000.5      59000  20200531.0  0.136255
# 958510    1    0  27.898  2459000.5      59000  20200531.0  0.223160
# 958511    1    0  21.510  2458994.5      58994  20200525.0  0.292102
# 958513    1    0  26.419  2459000.5      59000  20200531.0  0.133246
#
#                a         q          i          om           w          ma  \
# ...

# %%
new_df = df.loc[(df['a'] <= upper_limit) & (df['a'] >= lower_limit)]
print('before removing outliers:', len(df))
print('after removing outliers:',len(new_df)) ##TRIMMING
print('outliers:', len(df)-len(new_df))
# Out:
# before removing outliers: 958524
# after removing outliers: 933605
# outliers: 24919

# %%
sns.boxplot(new_df['a'])
# Out:
# <Axes: >

# %%
sns.distplot(new_df['a'])
# Out:
# C:\Users\deagn\AppData\Local\Temp\ipykernel_8964\2551995574.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(new_df['a'])
# <Axes: xlabel='a', ylabel='Density'>

# %%
new_df = df.copy() ## CAPPING
new_df.loc[(new_df['a']>upper_limit), 'a'] = upper_limit
new_df.loc[(new_df['a']<lower_limit), 'a'] = lower_limit

# %%
sns.boxplot(new_df['a'])
# Out:
# <Axes: >

# %%
sns.distplot(new_df['a'])
# Out:
# C:\Users\deagn\AppData\Local\Temp\ipykernel_8964\2551995574.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(new_df['a'])
# <Axes: xlabel='a', ylabel='Density'>

# %% [markdown]
# Percentile Method

# %%
upper_limit = df['a'].quantile(0.99)
lower_limit = df['a'].quantile(0.01)
print('upper limit:', upper_limit)
print('lower limit:', lower_limit)
# Out:
# upper limit: 5.174383524442131
# lower limit: 1.559982582745172

# %%
df.loc[(df['a'] > upper_limit) | (df['a'] < lower_limit)]
# Out:
#         neo  pha       H      epoch  epoch_mjd   epoch_cal         e  \
# 432       1    0  10.400  2459000.5      59000  20200531.0  0.222951
# 587       0    0   8.300  2459000.5      59000  20200531.0  0.147122
# 616       0    0   8.200  2459000.5      59000  20200531.0  0.138967
# 623       0    0   7.200  2459000.5      59000  20200531.0  0.022797
# 883       0    0   8.700  2459000.5      59000  20200531.0  0.123272
# ...     ...  ...     ...        ...        ...         ...       ...
# 958505    1    0  24.371  2458991.5      58991  20200522.0  0.358703
# 958507    1    0  29.913  2459000.5      59000  20200531.0  0.136255
# 958510    1    0  27.898  2459000.5      59000  20200531.0  0.223160
# 958511    1    0  21.510  2458994.5      58994  20200525.0  0.292102
# 958513    1    0  26.419  2459000.5      59000  20200531.0  0.133246
#
#                a         q          i          om           w          ma  \
# ...

# %%
new_df = df.loc[(df['a'] <= upper_limit) & (df['a'] >= lower_limit)]
print('before removing outliers:', len(df))
print('after removing outliers:',len(new_df))  #TRIMMING
print('outliers:', len(df)-len(new_df))
# Out:
# before removing outliers: 958524
# after removing outliers: 939352
# outliers: 19172

# %%
sns.boxplot(new_df['a'])
# Out:
# <Axes: >

# %%
sns.distplot(new_df['a'])
# Out:
# C:\Users\deagn\AppData\Local\Temp\ipykernel_8964\2551995574.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(new_df['a'])
# <Axes: xlabel='a', ylabel='Density'>

# %%
new_df = df.copy()
new_df.loc[(new_df['a']>upper_limit), 'a'] = upper_limit
new_df.loc[(new_df['a']<lower_limit), 'a'] = lower_limit #CAPPING

# %%
sns.boxplot(new_df['a'])
# Out:
# <Axes: >

# %%
sns.distplot(new_df['a'])
# Out:
# C:\Users\deagn\AppData\Local\Temp\ipykernel_8964\2551995574.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(new_df['a'])
# <Axes: xlabel='a', ylabel='Density'>
